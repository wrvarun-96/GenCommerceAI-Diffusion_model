# %% [markdown]
# ##Part 2: Fine-tuning Stable Diffusion

# %% [markdown]
# To train stable diffusion on our images, we can use a technique called fine-tuning, which involves taking a pre-trained stable diffusion model and training it further on a new dataset. In this way, we can leverage the knowledge already learned by the pre-trained model and adapt it to the new dataset, allowing us to achieve better performance with less training time. In this context, we will be fine-tuning a stable diffusion model on our own images, which will enable us to generate new images that are similar in style and content to our original dataset. Once we have fine-tuned the model, we will be able to use it for inference, generating new images on demand.

# %%
# !cd /content/
# !git clone https://github.com/huggingface/diffusers.git
# !pip install ./diffusers
# !pip install -U -r /content/diffusers/examples/text_to_image/requirements.txt
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 23225, done.
# remote: Counting objects: 100% (550/550), done.
# remote: Compressing objects: 100% (295/295), done.
# remote: Total 23225 (delta 354), reused 370 (delta 226), pack-reused 22675
# Receiving objects: 100% (23225/23225), 15.77 MiB | 12.55 MiB/s, done.
# Resolving deltas: 100% (16570/16570), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing ./diffusers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting huggingface-hub>=0.13.2
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 20.7 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from diffusers==0.15.0.dev0) (2.27.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from diffusers==0.15.0.dev0) (8.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from diffusers==0.15.0.dev0) (3.10.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from diffusers==0.15.0.dev0) (1.22.4)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.9/dist-packages (from diffusers==0.15.0.dev0) (6.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from diffusers==0.15.0.dev0) (2022.10.31)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.15.0.dev0) (6.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.15.0.dev0) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.15.0.dev0) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.15.0.dev0) (23.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata->diffusers==0.15.0.dev0) (3.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers==0.15.0.dev0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers==0.15.0.dev0) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers==0.15.0.dev0) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers==0.15.0.dev0) (1.26.15)
# Building wheels for collected packages: diffusers
#   Building wheel for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.15.0.dev0-py3-none-any.whl size=832622 sha256=2572ce6d383b3d43223502a7572cd374781c59cd374d8781e1758e7869cbb632
#   Stored in directory: /tmp/pip-ephem-wheel-cache-z1acbwnc/wheels/bd/1c/ea/a9c409b587aa6f3abca1bf1ce8eb592b2b541e5f26f5a4f44b
# Successfully built diffusers
# Installing collected packages: huggingface-hub, diffusers
# Successfully installed diffusers-0.15.0.dev0 huggingface-hub-0.13.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting accelerate
#   Downloading accelerate-0.18.0-py3-none-any.whl (215 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.3/215.3 kB 17.9 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from -r /content/diffusers/examples/text_to_image/requirements.txt (line 2)) (0.15.1+cu118)
# Collecting transformers>=4.25.1
#   Downloading transformers-4.27.4-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 109.1 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.11.0-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 48.1 MB/s eta 0:00:00
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.9/dist-packages (from -r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (2.12.1)
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.9/dist-packages (from -r /content/diffusers/examples/text_to_image/requirements.txt (line 7)) (3.1.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from accelerate->-r /content/diffusers/examples/text_to_image/requirements.txt (line 1)) (5.9.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from accelerate->-r /content/diffusers/examples/text_to_image/requirements.txt (line 1)) (23.0)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from accelerate->-r /content/diffusers/examples/text_to_image/requirements.txt (line 1)) (2.0.0+cu118)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from accelerate->-r /content/diffusers/examples/text_to_image/requirements.txt (line 1)) (1.22.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from accelerate->-r /content/diffusers/examples/text_to_image/requirements.txt (line 1)) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torchvision->-r /content/diffusers/examples/text_to_image/requirements.txt (line 2)) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->-r /content/diffusers/examples/text_to_image/requirements.txt (line 2)) (8.4.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.4.0->accelerate->-r /content/diffusers/examples/text_to_image/requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch>=1.4.0->accelerate->-r /content/diffusers/examples/text_to_image/requirements.txt (line 1)) (3.10.7)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.4.0->accelerate->-r /content/diffusers/examples/text_to_image/requirements.txt (line 1)) (3.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.4.0->accelerate->-r /content/diffusers/examples/text_to_image/requirements.txt (line 1)) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.4.0->accelerate->-r /content/diffusers/examples/text_to_image/requirements.txt (line 1)) (1.11.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.4.0->accelerate->-r /content/diffusers/examples/text_to_image/requirements.txt (line 1)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.4.0->accelerate->-r /content/diffusers/examples/text_to_image/requirements.txt (line 1)) (16.0.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.25.1->-r /content/diffusers/examples/text_to_image/requirements.txt (line 3)) (2022.10.31)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.25.1->-r /content/diffusers/examples/text_to_image/requirements.txt (line 3)) (0.13.4)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.25.1->-r /content/diffusers/examples/text_to_image/requirements.txt (line 3)) (4.65.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 104.2 MB/s eta 0:00:00
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 29.2 MB/s eta 0:00:00
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 18.3 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 73.4 MB/s eta 0:00:00
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets->-r /content/diffusers/examples/text_to_image/requirements.txt (line 4)) (1.4.4)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets->-r /content/diffusers/examples/text_to_image/requirements.txt (line 4)) (2023.3.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets->-r /content/diffusers/examples/text_to_image/requirements.txt (line 4)) (9.0.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 20.9 MB/s eta 0:00:00
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.9/dist-packages (from ftfy->-r /content/diffusers/examples/text_to_image/requirements.txt (line 5)) (0.2.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (2.2.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (3.4.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (67.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (2.17.1)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (3.20.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (1.53.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (0.40.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2->-r /content/diffusers/examples/text_to_image/requirements.txt (line 7)) (2.1.2)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 35.3 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 18.7 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 24.2 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets->-r /content/diffusers/examples/text_to_image/requirements.txt (line 4)) (22.2.0)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets->-r /content/diffusers/examples/text_to_image/requirements.txt (line 4)) (2.0.12)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (6.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision->-r /content/diffusers/examples/text_to_image/requirements.txt (line 2)) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision->-r /content/diffusers/examples/text_to_image/requirements.txt (line 2)) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision->-r /content/diffusers/examples/text_to_image/requirements.txt (line 2)) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets->-r /content/diffusers/examples/text_to_image/requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets->-r /content/diffusers/examples/text_to_image/requirements.txt (line 4)) (2022.7.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (3.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.4.0->accelerate->-r /content/diffusers/examples/text_to_image/requirements.txt (line 1)) (1.3.0)
# Installing collected packages: tokenizers, xxhash, multidict, ftfy, frozenlist, dill, async-timeout, yarl, responses, multiprocess, aiosignal, transformers, aiohttp, datasets, accelerate
# Successfully installed accelerate-0.18.0 aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.11.0 dill-0.3.6 frozenlist-1.3.3 ftfy-6.1.1 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 tokenizers-0.13.3 transformers-4.27.4 xxhash-3.2.0 yarl-1.8.2

# %% [markdown]
# Let's configure HuggingFace Accelerate, a platform for allowing us to automatically configure our system to be able to run our training script. You can learn more about Accelerate [here](https://huggingface.co/docs/accelerate/index).

# %%
# !nvidia-smi
# Out:
# Mon Apr 10 17:16:35 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    48W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !accelerate config default --mixed_precision fp16
# Out:
# 2023-04-10 17:17:20.518495: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# accelerate configuration saved at /root/.cache/huggingface/accelerate/default_config.yaml

# %% [markdown]
# Time to configure our environment variables. For this, we want to tell the script our model name, dataset name, and where we would like it to output the model. We will be automatically pushing the model directly to HuggingFace Hub which will require us to login to our HuggingFace account using the token provided through your HuggingFace account settings.

# %%
import os

os.environ['MODEL_NAME'] = f'CompVis/stable-diffusion-v1-2'
os.environ['DATASET_NAME'] = f'Ali-fb/martin_valen_dataset'
os.environ['OUTPUT_DIR'] = f'sd_martin_valen-model-v1-2_400_demo'

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# Run our training script using HuggingFace accelerate. We'll be inputing our dataset and model with 400 steps (selected) and 134 epochs (default). The model will then be automatically pushed to the hub.

# %%
# !accelerate launch diffusers/examples/text_to_image/train_text_to_image.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --dataset_name=$DATASET_NAME \
  --use_ema \
  --resolution=512 --center_crop --random_flip \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --gradient_checkpointing \
  --mixed_precision="fp16" \
  --max_train_steps=400 \
  --learning_rate=1e-05 \
  --max_grad_norm=1 \
  --push_to_hub \
  --checkpointing_steps=100000 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --output_dir=$OUTPUT_DIR
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# pytorch_model.bin:  81% 981M/1.22G [03:43<01:05, 3.58MB/s]
#
#
# diffusion_pytorch_model.bin:  29% 980M/3.44G [03:43<12:03, 3.40MB/s]
#
#
#
#
#
# pytorch_model.bin:  81% 982M/1.22G [03:43<00:53, 4.39MB/s]
#
#
# diffusion_pytorch_model.bin:  29% 983M/3.44G [03:44<08:04, 5.06MB/s]
#
#
#
#
#
# pytorch_model.bin:  81% 986M/1.22G [03:44<00:34, 6.69MB/s]
#
#
# diffusion_pytorch_model.bin:  29% 985M/3.44G [03:44<06:55, 5.90MB/s]
#
#
#
#
#
# pytorch_model.bin:  81% 989M/1.22G [03:44<00:26, 8.68MB/s]
#
#
# diffusion_pytorch_model.bin:  29% 989M/3.44G [03:44<04:51, 8.41MB/s]
#
#
#
#
#
# pytorch_model.bin:  82% 991M/1.22G [03:44<00:25, 8.66MB/s]
#
#
# diffusion_pytorch_model.bin:  29% 991M/3.44G [03:44<04:53, 8.33MB/s]
#
#
# diffusion_pytorch_model.bin:  29% 992M/3.44G [03:46<11:39, 3.49MB/s]
#
#
#
#
#
# pytorch_model.bin:  82% 992M/1.22G [03:46<01:24, 2.65MB/s]
#
#
# diffusion_pytorch_model.bin:  29% 993M/3.44G [03:46<15:13, 2.68MB/s]
#
#
#
#
#
# pytorch_model.bin:  82% 993M/1.22G [03:46<01:22, 2.71MB/s]
#
#
# diffusion_pytorch_model.bin:  29% 993M/3.44G [03:46<15:25, 2.64MB/s]
#
#
#
#
#
# pytorch_model.bin:  82% 994M/1.22G [03:46<01:21, 2.72MB/s]
#
#
# diffusion_pytorch_model.bin:  29% 994M/3.44G [03:47<15:59, 2.55MB/s]
#
#
#
#
#
# pytorch_model.bin:  82% 995M/1.22G [03:47<01:10, 3.15MB/s]
#
#
# diffusion_pytorch_model.bin:  29% 996M/3.44G [03:47<11:40, 3.49MB/s]
#
#
#
#
#
# pytorch_model.bin:  82% 996M/1.22G [03:47<00:59, 3.68MB/s]
#
#
# diffusion_pytorch_model.bin:  29% 997M/3.44G [03:47<09:59, 4.07MB/s]
#
#
#
#
#
# pytorch_model.bin:  82% 998M/1.22G [03:47<00:50, 4.31MB/s]
#
#
# diffusion_pytorch_model.bin:  29% 999M/3.44G [03:47<07:47, 5.22MB/s]
#
#
#
#
#
# pytorch_model.bin:  82% 999M/1.22G [03:47<00:44, 4.86MB/s]
#
#
# diffusion_pytorch_model.bin:  29% 1.00G/3.44G [03:48<05:08, 7.89MB/s]
#
#
#
#
#
# pytorch_model.bin:  82% 1.00G/1.22G [03:48<00:28, 7.38MB/s]
#
#
# diffusion_pytorch_model.bin:  29% 1.01G/3.44G [03:48<04:12, 9.65MB/s]
#
#
#
#
#
# pytorch_model.bin:  83% 1.01G/1.22G [03:48<00:22, 9.21MB/s]
#
#
# diffusion_pytorch_model.bin:  29% 1.01G/3.44G [03:49<08:23, 4.83MB/s]
#
#
#
#
#
# pytorch_model.bin:  83% 1.01G/1.22G [03:49<00:44, 4.69MB/s]
#
#
# diffusion_pytorch_model.bin:  29% 1.01G/3.44G [03:50<12:56, 3.13MB/s]
#
#
#
#
#
# pytorch_model.bin:  83% 1.01G/1.22G [03:50<01:08, 3.03MB/s]
#
#
# diffusion_pytorch_model.bin:  29% 1.01G/3.44G [03:50<13:11, 3.07MB/s]
#
#
#
#
#
# pytorch_model.bin:  83% 1.01G/1.22G [03:50<01:09, 2.98MB/s]
#
#
# diffusion_pytorch_model.bin:  29% 1.01G/3.44G [03:50<13:46, 2.94MB/s]
#
#
#
#
#
# pytorch_model.bin:  83% 1.01G/1.22G [03:50<01:12, 2.85MB/s]
#
#
#
#
#
# pytorch_model.bin:  83% 1.01G/1.22G [03:50<00:56, 3.62MB/s]
#
#
# diffusion_pytorch_model.bin:  29% 1.01G/3.44G [03:51<10:08, 3.98MB/s]
#
#
#
#
#
# pytorch_model.bin:  83% 1.01G/1.22G [03:51<00:40, 4.99MB/s]
#
#
# diffusion_pytorch_model.bin:  30% 1.01G/3.44G [03:51<08:12, 4.92MB/s]
#
#
#
#
#
# pytorch_model.bin:  83% 1.02G/1.22G [03:51<00:36, 5.51MB/s]
#
#
# diffusion_pytorch_model.bin:  30% 1.02G/3.44G [03:51<05:39, 7.14MB/s]
#
#
#
#
#
# pytorch_model.bin:  84% 1.02G/1.22G [03:51<00:30, 6.45MB/s]
#
#
# diffusion_pytorch_model.bin:  30% 1.02G/3.44G [03:51<05:17, 7.61MB/s]
#
#
#
#
#
# pytorch_model.bin:  84% 1.02G/1.22G [03:51<00:21, 9.24MB/s]
#
#
# diffusion_pytorch_model.bin:  30% 1.02G/3.44G [03:52<04:21, 9.25MB/s]
#
#
#
#
#
# pytorch_model.bin:  84% 1.02G/1.22G [03:52<00:21, 8.97MB/s]
#
#
#
#
#
# pytorch_model.bin:  84% 1.02G/1.22G [03:53<00:48, 3.98MB/s]
#
#
# diffusion_pytorch_model.bin:  30% 1.02G/3.44G [03:53<13:12, 3.04MB/s]
#
#
#
#
#
# pytorch_model.bin:  84% 1.02G/1.22G [03:53<01:15, 2.54MB/s]
#
#
# diffusion_pytorch_model.bin:  30% 1.03G/3.44G [03:53<13:20, 3.01MB/s]
#
#
# diffusion_pytorch_model.bin:  30% 1.03G/3.44G [03:54<13:05, 3.07MB/s]
#
#
#
#
#
# pytorch_model.bin:  84% 1.03G/1.22G [03:54<01:15, 2.52MB/s]
#
#
# diffusion_pytorch_model.bin:  30% 1.03G/3.44G [03:54<13:34, 2.96MB/s]
#
#
#
#
#
# pytorch_model.bin:  84% 1.03G/1.22G [03:54<01:00, 3.14MB/s]
#
#
# diffusion_pytorch_model.bin:  30% 1.03G/3.44G [03:54<11:56, 3.36MB/s]
#
#
#
#
#
# pytorch_model.bin:  85% 1.03G/1.22G [03:54<00:50, 3.74MB/s]
#
#
# diffusion_pytorch_model.bin:  30% 1.03G/3.44G [03:54<08:54, 4.51MB/s]
#
#
#
#
#
# pytorch_model.bin:  85% 1.03G/1.22G [03:54<00:43, 4.33MB/s]
#
#
# diffusion_pytorch_model.bin:  30% 1.03G/3.44G [03:54<07:29, 5.36MB/s]
#
#
#
#
#
# pytorch_model.bin:  85% 1.03G/1.22G [03:55<00:37, 4.95MB/s]
#
#
# diffusion_pytorch_model.bin:  30% 1.03G/3.44G [03:55<05:14, 7.63MB/s]
#
#
#
#
#
# pytorch_model.bin:  85% 1.03G/1.22G [03:55<00:25, 7.18MB/s]
#
#
# diffusion_pytorch_model.bin:  30% 1.04G/3.44G [03:55<04:10, 9.57MB/s]
#
#
#
#
#
# pytorch_model.bin:  85% 1.04G/1.22G [03:55<00:19, 9.26MB/s]
#
#
#
#
#
# pytorch_model.bin:  85% 1.04G/1.22G [03:55<00:19, 9.14MB/s]
#
#
# diffusion_pytorch_model.bin:  30% 1.04G/3.44G [03:56<08:15, 4.84MB/s]
#
#
#
#
#
# pytorch_model.bin:  86% 1.04G/1.22G [03:57<01:03, 2.76MB/s]
#
#
#
#
#
# pytorch_model.bin:  86% 1.04G/1.22G [03:57<01:02, 2.81MB/s]
#
#
# diffusion_pytorch_model.bin:  30% 1.04G/3.44G [03:57<14:13, 2.81MB/s]
#
#
#
#
#
# pytorch_model.bin:  86% 1.04G/1.22G [03:57<01:02, 2.80MB/s]
#
#
# diffusion_pytorch_model.bin:  30% 1.04G/3.44G [03:57<14:19, 2.79MB/s]
#
#
#
#
#
# pytorch_model.bin:  86% 1.04G/1.22G [03:57<00:53, 3.22MB/s]
#
#
# diffusion_pytorch_model.bin:  30% 1.04G/3.44G [03:58<14:45, 2.71MB/s]
#
#
# diffusion_pytorch_model.bin:  30% 1.04G/3.44G [03:58<12:17, 3.25MB/s]
#
#
#
#
#
# pytorch_model.bin:  86% 1.04G/1.22G [03:58<00:51, 3.31MB/s]
#
#
# diffusion_pytorch_model.bin:  30% 1.05G/3.44G [03:58<08:42, 4.58MB/s]
#
#
#
#
#
# pytorch_model.bin:  86% 1.05G/1.22G [03:58<00:40, 4.23MB/s]
#
#
# diffusion_pytorch_model.bin:  30% 1.05G/3.44G [03:58<07:24, 5.39MB/s]
#
#
#
#
#
# pytorch_model.bin:  86% 1.05G/1.22G [03:58<00:23, 6.93MB/s]
#
#
# diffusion_pytorch_model.bin:  31% 1.05G/3.44G [03:58<06:21, 6.26MB/s]
#
#
#
#
#
# pytorch_model.bin:  87% 1.05G/1.22G [03:59<00:18, 8.82MB/s]
#
#
# diffusion_pytorch_model.bin:  31% 1.05G/3.44G [03:59<04:49, 8.25MB/s]
#
#
#
#
#
# pytorch_model.bin:  87% 1.06G/1.22G [03:59<00:18, 8.86MB/s]
#
#
# diffusion_pytorch_model.bin:  31% 1.06G/3.44G [03:59<04:02, 9.81MB/s]
#
#
#
#
#
# pytorch_model.bin:  87% 1.06G/1.22G [04:00<00:50, 3.14MB/s]
#
#
# diffusion_pytorch_model.bin:  31% 1.06G/3.44G [04:01<13:26, 2.95MB/s]
#
#
#
#
#
# pytorch_model.bin:  87% 1.06G/1.22G [04:01<00:57, 2.79MB/s]
#
#
#
#
#
# pytorch_model.bin:  87% 1.06G/1.22G [04:01<00:57, 2.75MB/s]
#
#
# diffusion_pytorch_model.bin:  31% 1.06G/3.44G [04:01<14:27, 2.75MB/s]
#
#
#
#
#
# pytorch_model.bin:  87% 1.06G/1.22G [04:01<00:47, 3.30MB/s]
#
#
# diffusion_pytorch_model.bin:  31% 1.06G/3.44G [04:01<12:08, 3.27MB/s]
#
#
# diffusion_pytorch_model.bin:  31% 1.06G/3.44G [04:01<10:42, 3.70MB/s]
#
#
#
#
#
# pytorch_model.bin:  87% 1.06G/1.22G [04:02<00:46, 3.35MB/s]
#
#
# diffusion_pytorch_model.bin:  31% 1.06G/3.44G [04:02<09:07, 4.34MB/s]
#
#
#
#
#
# pytorch_model.bin:  87% 1.06G/1.22G [04:02<00:35, 4.31MB/s]
#
#
# diffusion_pytorch_model.bin:  31% 1.06G/3.44G [04:02<08:08, 4.86MB/s]
#
#
#
#
#
# pytorch_model.bin:  88% 1.07G/1.22G [04:02<00:21, 7.06MB/s]
#
#
# diffusion_pytorch_model.bin:  31% 1.07G/3.44G [04:02<05:30, 7.17MB/s]
#
#
#
#
#
# pytorch_model.bin:  88% 1.07G/1.22G [04:02<00:19, 7.52MB/s]
#
#
# diffusion_pytorch_model.bin:  31% 1.07G/3.44G [04:02<04:24, 8.95MB/s]
#
#
#
#
#
# pytorch_model.bin:  88% 1.07G/1.22G [04:02<00:15, 9.33MB/s]
#
#
# diffusion_pytorch_model.bin:  31% 1.07G/3.44G [04:03<04:29, 8.79MB/s]
#
#
#
#
#
# pytorch_model.bin:  88% 1.07G/1.22G [04:04<00:46, 3.07MB/s]
#
#
# diffusion_pytorch_model.bin:  31% 1.07G/3.44G [04:04<14:07, 2.79MB/s]
#
#
#
#
#
# pytorch_model.bin:  88% 1.07G/1.22G [04:05<00:51, 2.78MB/s]
#
#
# diffusion_pytorch_model.bin:  31% 1.07G/3.44G [04:05<15:34, 2.53MB/s]
#
#
#
#
#
# pytorch_model.bin:  88% 1.07G/1.22G [04:05<00:41, 3.41MB/s]
#
#
# diffusion_pytorch_model.bin:  31% 1.07G/3.44G [04:05<12:02, 3.27MB/s]
#
#
#
#
#
# pytorch_model.bin:  89% 1.08G/1.22G [04:05<00:40, 3.42MB/s]
#
#
# diffusion_pytorch_model.bin:  31% 1.08G/3.44G [04:05<11:42, 3.36MB/s]
#
#
#
#
#
# pytorch_model.bin:  89% 1.08G/1.22G [04:05<00:26, 5.18MB/s]
#
#
# diffusion_pytorch_model.bin:  31% 1.08G/3.44G [04:06<09:27, 4.16MB/s]
#
#
#
#
#
# pytorch_model.bin:  89% 1.08G/1.22G [04:06<00:23, 5.83MB/s]
#
#
# diffusion_pytorch_model.bin:  31% 1.08G/3.44G [04:06<05:58, 6.56MB/s]
#
#
#
#
#
# pytorch_model.bin:  89% 1.09G/1.22G [04:06<00:15, 8.32MB/s]
#
#
# diffusion_pytorch_model.bin:  32% 1.09G/3.44G [04:06<04:39, 8.42MB/s]
#
#
#
#
#
# pytorch_model.bin:  89% 1.09G/1.22G [04:06<00:15, 8.30MB/s]
#
#
# diffusion_pytorch_model.bin:  32% 1.09G/3.44G [04:06<04:37, 8.46MB/s]
#
#
#
#
#
# pytorch_model.bin:  89% 1.09G/1.22G [04:07<00:32, 3.96MB/s]
#
#
# diffusion_pytorch_model.bin:  32% 1.09G/3.44G [04:08<13:35, 2.88MB/s]
#
#
#
#
#
# pytorch_model.bin:  90% 1.09G/1.22G [04:08<00:49, 2.59MB/s]
#
#
#
#
#
# pytorch_model.bin:  90% 1.09G/1.22G [04:08<00:49, 2.57MB/s]
#
#
# diffusion_pytorch_model.bin:  32% 1.09G/3.44G [04:08<14:57, 2.62MB/s]
#
#
#
#
#
# pytorch_model.bin:  90% 1.09G/1.22G [04:08<00:37, 3.36MB/s]
#
#
# diffusion_pytorch_model.bin:  32% 1.09G/3.44G [04:08<14:58, 2.61MB/s]
#
#
# diffusion_pytorch_model.bin:  32% 1.09G/3.44G [04:09<11:22, 3.44MB/s]
#
#
#
#
#
# pytorch_model.bin:  90% 1.09G/1.22G [04:09<00:35, 3.43MB/s]
#
#
# diffusion_pytorch_model.bin:  32% 1.09G/3.44G [04:09<08:55, 4.38MB/s]
#
#
#
#
#
# pytorch_model.bin:  90% 1.09G/1.22G [04:09<00:28, 4.34MB/s]
#
#
# diffusion_pytorch_model.bin:  32% 1.10G/3.44G [04:09<07:31, 5.19MB/s]
#
#
#
#
#
# pytorch_model.bin:  90% 1.10G/1.22G [04:09<00:17, 6.63MB/s]
#
#
# diffusion_pytorch_model.bin:  32% 1.10G/3.44G [04:09<05:10, 7.55MB/s]
#
#
#
#
#
# pytorch_model.bin:  91% 1.10G/1.22G [04:10<00:13, 8.81MB/s]
#
#
# diffusion_pytorch_model.bin:  32% 1.10G/3.44G [04:10<04:14, 9.20MB/s]
#
#
#
#
#
# pytorch_model.bin:  91% 1.10G/1.22G [04:10<00:12, 8.72MB/s]
#
#
# diffusion_pytorch_model.bin:  32% 1.10G/3.44G [04:10<04:19, 8.99MB/s]
#
#
# diffusion_pytorch_model.bin:  32% 1.10G/3.44G [04:11<13:51, 2.81MB/s]
#
#
#
#
#
# pytorch_model.bin:  91% 1.10G/1.22G [04:12<00:42, 2.63MB/s]
#
#
#
#
#
# pytorch_model.bin:  91% 1.11G/1.22G [04:12<00:41, 2.71MB/s]
#
#
# diffusion_pytorch_model.bin:  32% 1.11G/3.44G [04:12<14:54, 2.61MB/s]
#
#
#
#
#
# pytorch_model.bin:  91% 1.11G/1.22G [04:12<00:40, 2.71MB/s]
#
#
# diffusion_pytorch_model.bin:  32% 1.11G/3.44G [04:12<11:57, 3.25MB/s]
#
#
#
#
#
# pytorch_model.bin:  91% 1.11G/1.22G [04:12<00:41, 2.64MB/s]
#
#
#
#
#
# pytorch_model.bin:  91% 1.11G/1.22G [04:12<00:33, 3.20MB/s]
#
#
# diffusion_pytorch_model.bin:  32% 1.11G/3.44G [04:13<11:52, 3.27MB/s]
#
#
#
#
#
# pytorch_model.bin:  91% 1.11G/1.22G [04:13<00:24, 4.28MB/s]
#
#
# diffusion_pytorch_model.bin:  32% 1.11G/3.44G [04:13<07:42, 5.03MB/s]
#
#
#
#
#
# pytorch_model.bin:  91% 1.11G/1.22G [04:13<00:20, 5.23MB/s]
#
#
# diffusion_pytorch_model.bin:  32% 1.11G/3.44G [04:13<06:45, 5.74MB/s]
#
#
#
#
#
# pytorch_model.bin:  92% 1.11G/1.22G [04:13<00:13, 7.65MB/s]
#
#
# diffusion_pytorch_model.bin:  32% 1.12G/3.44G [04:13<04:43, 8.18MB/s]
#
#
#
#
#
# pytorch_model.bin:  92% 1.12G/1.22G [04:13<00:10, 9.43MB/s]
#
#
# diffusion_pytorch_model.bin:  33% 1.12G/3.44G [04:13<04:41, 8.24MB/s]
#
#
#
#
#
# pytorch_model.bin:  92% 1.12G/1.22G [04:14<00:19, 4.81MB/s]
#
#
# diffusion_pytorch_model.bin:  33% 1.12G/3.44G [04:14<10:00, 3.86MB/s]
#
#
#
#
#
# pytorch_model.bin:  92% 1.12G/1.22G [04:15<00:30, 3.11MB/s]
#
#
# diffusion_pytorch_model.bin:  33% 1.12G/3.44G [04:15<15:08, 2.55MB/s]
#
#
#
#
#
# pytorch_model.bin:  92% 1.12G/1.22G [04:16<00:31, 3.05MB/s]
#
#
# diffusion_pytorch_model.bin:  33% 1.12G/3.44G [04:16<15:14, 2.53MB/s]
#
#
#
#
#
# pytorch_model.bin:  92% 1.12G/1.22G [04:16<00:32, 2.93MB/s]
#
#
# diffusion_pytorch_model.bin:  33% 1.12G/3.44G [04:16<15:42, 2.46MB/s]
#
#
#
#
#
# pytorch_model.bin:  92% 1.12G/1.22G [04:16<00:25, 3.67MB/s]
#
#
# diffusion_pytorch_model.bin:  33% 1.12G/3.44G [04:16<11:12, 3.44MB/s]
#
#
# diffusion_pytorch_model.bin:  33% 1.13G/3.44G [04:16<08:28, 4.54MB/s]
#
#
#
#
#
# pytorch_model.bin:  93% 1.13G/1.22G [04:16<00:23, 3.93MB/s]
#
#
# diffusion_pytorch_model.bin:  33% 1.13G/3.44G [04:16<07:07, 5.41MB/s]
#
#
# diffusion_pytorch_model.bin:  33% 1.13G/3.44G [04:17<04:59, 7.72MB/s]
#
#
#
#
#
# pytorch_model.bin:  93% 1.13G/1.22G [04:17<00:22, 3.95MB/s]
#
#
# diffusion_pytorch_model.bin:  33% 1.13G/3.44G [04:17<04:04, 9.42MB/s]
#
#
# diffusion_pytorch_model.bin:  33% 1.14G/3.44G [04:17<04:14, 9.03MB/s]
#
#
#
#
#
# pytorch_model.bin:  93% 1.13G/1.22G [04:17<00:21, 3.97MB/s]
#
#
#
#
#
# pytorch_model.bin:  93% 1.13G/1.22G [04:18<00:22, 3.85MB/s]
#
#
#
#
#
# pytorch_model.bin:  93% 1.13G/1.22G [04:18<00:21, 3.82MB/s]
#
#
#
#
#
# pytorch_model.bin:  93% 1.13G/1.22G [04:18<00:19, 4.25MB/s]
#
#
# diffusion_pytorch_model.bin:  33% 1.14G/3.44G [04:19<13:49, 2.78MB/s]
#
#
#
#
#
# pytorch_model.bin:  93% 1.14G/1.22G [04:19<00:19, 4.23MB/s]
#
#
# diffusion_pytorch_model.bin:  33% 1.14G/3.44G [04:19<15:14, 2.52MB/s]
#
#
# diffusion_pytorch_model.bin:  33% 1.14G/3.44G [04:19<11:55, 3.21MB/s]
#
#
# diffusion_pytorch_model.bin:  33% 1.14G/3.44G [04:20<11:38, 3.29MB/s]
#
#
# diffusion_pytorch_model.bin:  33% 1.14G/3.44G [04:20<07:34, 5.05MB/s]
#
#
# diffusion_pytorch_model.bin:  33% 1.15G/3.44G [04:20<06:37, 5.77MB/s]
#
#
#
#
#
# pytorch_model.bin:  93% 1.14G/1.22G [04:20<00:43, 1.85MB/s]
#
#
# diffusion_pytorch_model.bin:  33% 1.15G/3.44G [04:21<04:36, 8.27MB/s]
#
#
# diffusion_pytorch_model.bin:  33% 1.15G/3.44G [04:21<04:35, 8.31MB/s]
#
#
#
#
#
# pytorch_model.bin:  93% 1.14G/1.22G [04:21<00:54, 1.46MB/s]
#
#
#
#
#
# pytorch_model.bin:  93% 1.14G/1.22G [04:21<00:56, 1.42MB/s]
#
#
#
#
#
# pytorch_model.bin:  94% 1.14G/1.22G [04:21<00:43, 1.82MB/s]
#
#
#
#
#
# pytorch_model.bin:  94% 1.14G/1.22G [04:22<00:37, 2.06MB/s]
#
#
# diffusion_pytorch_model.bin:  34% 1.15G/3.44G [04:22<09:43, 3.92MB/s]
#
#
#
#
#
# pytorch_model.bin:  94% 1.14G/1.22G [04:22<00:22, 3.28MB/s]
#
#
#
#
#
# pytorch_model.bin:  94% 1.14G/1.22G [04:22<00:17, 4.25MB/s]
#
#
#
#
#
# pytorch_model.bin:  94% 1.15G/1.22G [04:23<00:10, 6.90MB/s]
#
#
# diffusion_pytorch_model.bin:  34% 1.15G/3.44G [04:23<14:46, 2.58MB/s]
#
#
#
#
#
# pytorch_model.bin:  95% 1.15G/1.22G [04:23<00:07, 8.79MB/s]
#
#
# diffusion_pytorch_model.bin:  34% 1.15G/3.44G [04:23<14:52, 2.56MB/s]
#
#
#
#
#
# pytorch_model.bin:  95% 1.15G/1.22G [04:23<00:07, 8.49MB/s]
#
#
# diffusion_pytorch_model.bin:  34% 1.15G/3.44G [04:23<11:45, 3.24MB/s]
#
#
# diffusion_pytorch_model.bin:  34% 1.16G/3.44G [04:23<11:28, 3.31MB/s]
#
#
# diffusion_pytorch_model.bin:  34% 1.16G/3.44G [04:24<07:13, 5.26MB/s]
#
#
# diffusion_pytorch_model.bin:  34% 1.16G/3.44G [04:24<06:02, 6.27MB/s]
#
#
# diffusion_pytorch_model.bin:  34% 1.17G/3.44G [04:24<04:30, 8.41MB/s]
#
#
#
#
#
# pytorch_model.bin:  95% 1.15G/1.22G [04:24<00:21, 2.97MB/s]
#
#
#
#
#
# pytorch_model.bin:  95% 1.15G/1.22G [04:25<00:23, 2.64MB/s]
#
#
#
#
#
# pytorch_model.bin:  95% 1.15G/1.22G [04:25<00:23, 2.68MB/s]
#
#
#
#
#
# pytorch_model.bin:  95% 1.15G/1.22G [04:25<00:21, 2.81MB/s]
#
#
# diffusion_pytorch_model.bin:  34% 1.17G/3.44G [04:25<08:13, 4.60MB/s]
#
#
#
#
#
# pytorch_model.bin:  95% 1.16G/1.22G [04:25<00:17, 3.46MB/s]
#
#
#
#
#
# pytorch_model.bin:  95% 1.16G/1.22G [04:26<00:12, 4.56MB/s]
#
#
#
#
#
# pytorch_model.bin:  95% 1.16G/1.22G [04:26<00:10, 5.30MB/s]
#
#
#
#
#
# pytorch_model.bin:  96% 1.16G/1.22G [04:26<00:06, 7.82MB/s]
#
#
# diffusion_pytorch_model.bin:  34% 1.17G/3.44G [04:26<12:12, 3.10MB/s]
#
#
#
#
#
# pytorch_model.bin:  96% 1.17G/1.22G [04:26<00:05, 9.44MB/s]
#
#
# diffusion_pytorch_model.bin:  34% 1.17G/3.44G [04:26<12:21, 3.06MB/s]
#
#
# diffusion_pytorch_model.bin:  34% 1.17G/3.44G [04:27<12:17, 3.08MB/s]
#
#
# diffusion_pytorch_model.bin:  34% 1.17G/3.44G [04:27<09:37, 3.92MB/s]
#
#
# diffusion_pytorch_model.bin:  34% 1.17G/3.44G [04:27<08:00, 4.71MB/s]
#
#
#
#
#
# pytorch_model.bin:  96% 1.17G/1.22G [04:27<00:09, 4.90MB/s]
#
#
# diffusion_pytorch_model.bin:  34% 1.18G/3.44G [04:28<05:19, 7.08MB/s]
#
#
# diffusion_pytorch_model.bin:  34% 1.18G/3.44G [04:28<04:15, 8.83MB/s]
#
#
# diffusion_pytorch_model.bin:  34% 1.18G/3.44G [04:28<04:15, 8.82MB/s]
#
#
#
#
#
# pytorch_model.bin:  96% 1.17G/1.22G [04:28<00:15, 3.14MB/s]
#
#
#
#
#
# pytorch_model.bin:  96% 1.17G/1.22G [04:29<00:14, 3.11MB/s]
#
#
#
#
#
# pytorch_model.bin:  96% 1.17G/1.22G [04:29<00:14, 3.12MB/s]
#
#
#
#
#
# pytorch_model.bin:  96% 1.17G/1.22G [04:29<00:11, 3.86MB/s]
#
#
#
#
#
# pytorch_model.bin:  97% 1.17G/1.22G [04:30<00:11, 3.78MB/s]
#
#
# diffusion_pytorch_model.bin:  34% 1.18G/3.44G [04:30<12:59, 2.89MB/s]
#
#
#
#
#
# pytorch_model.bin:  97% 1.18G/1.22G [04:30<00:06, 6.06MB/s]
#
#
# diffusion_pytorch_model.bin:  34% 1.19G/3.44G [04:30<13:04, 2.87MB/s]
#
#
# diffusion_pytorch_model.bin:  34% 1.19G/3.44G [04:30<12:51, 2.92MB/s]
#
#
#
#
#
# pytorch_model.bin:  97% 1.18G/1.22G [04:30<00:05, 6.64MB/s]
#
#
# diffusion_pytorch_model.bin:  35% 1.19G/3.44G [04:30<13:19, 2.82MB/s]
#
#
#
#
#
# pytorch_model.bin:  97% 1.18G/1.22G [04:30<00:04, 7.68MB/s]
#
#
# diffusion_pytorch_model.bin:  35% 1.19G/3.44G [04:31<11:19, 3.31MB/s]
#
#
# diffusion_pytorch_model.bin:  35% 1.19G/3.44G [04:31<08:24, 4.46MB/s]
#
#
# diffusion_pytorch_model.bin:  35% 1.19G/3.44G [04:31<06:57, 5.38MB/s]
#
#
# diffusion_pytorch_model.bin:  35% 1.19G/3.44G [04:31<04:53, 7.65MB/s]
#
#
# diffusion_pytorch_model.bin:  35% 1.20G/3.44G [04:31<04:41, 7.98MB/s]
#
#
#
#
#
# pytorch_model.bin:  97% 1.18G/1.22G [04:31<00:08, 3.74MB/s]
#
#
# diffusion_pytorch_model.bin:  35% 1.20G/3.44G [04:32<03:54, 9.55MB/s]
#
#
#
#
#
# pytorch_model.bin:  97% 1.18G/1.22G [04:32<00:12, 2.51MB/s]
#
#
#
#
#
# pytorch_model.bin:  97% 1.19G/1.22G [04:33<00:12, 2.48MB/s]
#
#
#
#
#
# pytorch_model.bin:  98% 1.19G/1.22G [04:33<00:10, 2.88MB/s]
#
#
#
#
#
# pytorch_model.bin:  98% 1.19G/1.22G [04:33<00:08, 3.49MB/s]
#
#
#
#
#
# pytorch_model.bin:  98% 1.19G/1.22G [04:33<00:05, 4.50MB/s]
#
#
#
#
#
# pytorch_model.bin:  98% 1.19G/1.22G [04:33<00:04, 5.33MB/s]
#
#
# diffusion_pytorch_model.bin:  35% 1.20G/3.44G [04:34<14:11, 2.63MB/s]
#
#
#
#
#
# pytorch_model.bin:  98% 1.19G/1.22G [04:34<00:02, 7.46MB/s]
#
#
#
#
#
# pytorch_model.bin:  99% 1.20G/1.22G [04:34<00:01, 9.20MB/s]
#
#
# diffusion_pytorch_model.bin:  35% 1.20G/3.44G [04:34<15:21, 2.43MB/s]
#
#
#
#
#
# pytorch_model.bin:  99% 1.20G/1.22G [04:34<00:01, 8.92MB/s]
#
#
# diffusion_pytorch_model.bin:  35% 1.20G/3.44G [04:34<15:14, 2.45MB/s]
#
#
# diffusion_pytorch_model.bin:  35% 1.20G/3.44G [04:34<12:04, 3.09MB/s]
#
#
# diffusion_pytorch_model.bin:  35% 1.21G/3.44G [04:35<08:49, 4.22MB/s]
#
#
# diffusion_pytorch_model.bin:  35% 1.21G/3.44G [04:35<07:19, 5.07MB/s]
#
#
# diffusion_pytorch_model.bin:  35% 1.21G/3.44G [04:35<05:08, 7.22MB/s]
#
#
# diffusion_pytorch_model.bin:  35% 1.21G/3.44G [04:35<04:07, 8.98MB/s]
#
#
# diffusion_pytorch_model.bin:  35% 1.22G/3.44G [04:36<04:10, 8.88MB/s]
#
#
#
#
#
# pytorch_model.bin:  99% 1.20G/1.22G [04:36<00:06, 2.49MB/s]
#
#
#
#
#
# pytorch_model.bin:  99% 1.20G/1.22G [04:36<00:05, 2.56MB/s]
#
#
#
#
#
# pytorch_model.bin:  99% 1.20G/1.22G [04:36<00:05, 2.57MB/s]
#
#
#
#
#
# pytorch_model.bin:  99% 1.20G/1.22G [04:37<00:03, 3.35MB/s]
#
#
#
#
#
# pytorch_model.bin:  99% 1.21G/1.22G [04:37<00:02, 4.39MB/s]
#
#
#
#
#
# pytorch_model.bin:  99% 1.21G/1.22G [04:37<00:01, 5.22MB/s]
#
#
# diffusion_pytorch_model.bin:  35% 1.22G/3.44G [04:37<13:26, 2.76MB/s]
#
#
#
#
#
# pytorch_model.bin: 100% 1.21G/1.22G [04:37<00:00, 7.45MB/s]
#
#
#
#
#
# pytorch_model.bin: 100% 1.21G/1.22G [04:38<00:00, 9.18MB/s]
#
#
# diffusion_pytorch_model.bin:  35% 1.22G/3.44G [04:38<14:43, 2.51MB/s]
#
#
# diffusion_pytorch_model.bin:  35% 1.22G/3.44G [04:38<11:41, 3.16MB/s]
#
#
# diffusion_pytorch_model.bin:  35% 1.22G/3.44G [04:38<11:23, 3.24MB/s]
#
#
# diffusion_pytorch_model.bin:  36% 1.22G/3.44G [04:39<09:08, 4.04MB/s]
#
#
#
#
#
# pytorch_model.bin: 100% 1.22G/1.22G [04:39<00:00, 4.88MB/s]
#
#
# diffusion_pytorch_model.bin:  36% 1.23G/3.44G [04:39<05:43, 6.44MB/s]
#
#
# diffusion_pytorch_model.bin:  36% 1.23G/3.44G [04:39<04:28, 8.22MB/s]
#
#
# pytorch_model.bin: 100% 1.22G/1.22G [04:40<00:00, 4.34MB/s]
#
#
#
#
# Upload 6 LFS files:  50% 3/6 [04:40<06:22, 127.62s/it]
#
#
# diffusion_pytorch_model.bin:  36% 1.23G/3.44G [04:41<11:36, 3.17MB/s]
#
#
# diffusion_pytorch_model.bin:  36% 1.23G/3.44G [04:41<13:19, 2.76MB/s]
#
#
# diffusion_pytorch_model.bin:  36% 1.23G/3.44G [04:41<13:03, 2.81MB/s]
#
#
# diffusion_pytorch_model.bin:  36% 1.23G/3.44G [04:42<12:32, 2.93MB/s]
#
#
# diffusion_pytorch_model.bin:  36% 1.24G/3.44G [04:42<10:13, 3.59MB/s]
#
#
# diffusion_pytorch_model.bin:  36% 1.24G/3.44G [04:42<07:52, 4.66MB/s]
#
#
# diffusion_pytorch_model.bin:  36% 1.24G/3.44G [04:42<06:41, 5.48MB/s]
#
#
# diffusion_pytorch_model.bin:  36% 1.24G/3.44G [04:42<05:39, 6.48MB/s]
#
#
# diffusion_pytorch_model.bin:  36% 1.24G/3.44G [04:43<04:24, 8.30MB/s]
#
#
# diffusion_pytorch_model.bin:  36% 1.25G/3.44G [04:43<03:37, 10.1MB/s]
#
#
# diffusion_pytorch_model.bin:  36% 1.25G/3.44G [04:45<13:02, 2.80MB/s]
#
#
# diffusion_pytorch_model.bin:  36% 1.25G/3.44G [04:45<14:07, 2.58MB/s]
#
#
# diffusion_pytorch_model.bin:  36% 1.25G/3.44G [04:45<11:21, 3.21MB/s]
#
#
# diffusion_pytorch_model.bin:  36% 1.25G/3.44G [04:46<08:45, 4.15MB/s]
#
#
# diffusion_pytorch_model.bin:  37% 1.26G/3.44G [04:46<07:26, 4.89MB/s]
#
#
# diffusion_pytorch_model.bin:  37% 1.26G/3.44G [04:46<05:19, 6.83MB/s]
#
#
# diffusion_pytorch_model.bin:  37% 1.26G/3.44G [04:46<04:57, 7.32MB/s]
#
#
# diffusion_pytorch_model.bin:  37% 1.26G/3.44G [04:47<04:02, 8.95MB/s]
#
#
# diffusion_pytorch_model.bin:  37% 1.26G/3.44G [04:48<13:18, 2.72MB/s]
#
#
# diffusion_pytorch_model.bin:  37% 1.27G/3.44G [04:49<12:54, 2.81MB/s]
#
#
# diffusion_pytorch_model.bin:  37% 1.27G/3.44G [04:49<12:49, 2.82MB/s]
#
#
# diffusion_pytorch_model.bin:  37% 1.27G/3.44G [04:49<10:22, 3.49MB/s]
#
#
# diffusion_pytorch_model.bin:  37% 1.27G/3.44G [04:49<08:09, 4.43MB/s]
#
#
# diffusion_pytorch_model.bin:  37% 1.27G/3.44G [04:49<07:01, 5.14MB/s]
#
#
# diffusion_pytorch_model.bin:  37% 1.27G/3.44G [04:50<06:12, 5.81MB/s]
#
#
# diffusion_pytorch_model.bin:  37% 1.28G/3.44G [04:50<04:32, 7.94MB/s]
#
#
# diffusion_pytorch_model.bin:  37% 1.28G/3.44G [04:50<03:52, 9.28MB/s]
#
#
# diffusion_pytorch_model.bin:  37% 1.28G/3.44G [04:52<10:54, 3.30MB/s]
#
#
# diffusion_pytorch_model.bin:  37% 1.28G/3.44G [04:52<12:19, 2.92MB/s]
#
#
# diffusion_pytorch_model.bin:  37% 1.28G/3.44G [04:52<12:31, 2.87MB/s]
#
#
# diffusion_pytorch_model.bin:  37% 1.28G/3.44G [04:52<10:45, 3.34MB/s]
#
#
# diffusion_pytorch_model.bin:  37% 1.28G/3.44G [04:53<09:18, 3.86MB/s]
#
#
# diffusion_pytorch_model.bin:  37% 1.29G/3.44G [04:53<07:56, 4.52MB/s]
#
#
# diffusion_pytorch_model.bin:  37% 1.29G/3.44G [04:53<07:00, 5.11MB/s]
#
#
# diffusion_pytorch_model.bin:  38% 1.29G/3.44G [04:53<04:42, 7.59MB/s]
#
#
# diffusion_pytorch_model.bin:  38% 1.29G/3.44G [04:54<03:47, 9.41MB/s]
#
#
# diffusion_pytorch_model.bin:  38% 1.30G/3.44G [04:54<03:51, 9.24MB/s]
#
#
# diffusion_pytorch_model.bin:  38% 1.30G/3.44G [04:56<14:06, 2.53MB/s]
#
#
# diffusion_pytorch_model.bin:  38% 1.30G/3.44G [04:56<12:59, 2.75MB/s]
#
#
# diffusion_pytorch_model.bin:  38% 1.30G/3.44G [04:56<12:41, 2.81MB/s]
#
#
# diffusion_pytorch_model.bin:  38% 1.30G/3.44G [04:56<10:29, 3.40MB/s]
#
#
# diffusion_pytorch_model.bin:  38% 1.30G/3.44G [04:57<08:14, 4.32MB/s]
#
#
# diffusion_pytorch_model.bin:  38% 1.30G/3.44G [04:57<06:51, 5.19MB/s]
#
#
# diffusion_pytorch_model.bin:  38% 1.31G/3.44G [04:57<04:51, 7.32MB/s]
#
#
# diffusion_pytorch_model.bin:  38% 1.31G/3.44G [04:57<03:54, 9.06MB/s]
#
#
# diffusion_pytorch_model.bin:  38% 1.31G/3.44G [04:58<07:21, 4.82MB/s]
#
#
# diffusion_pytorch_model.bin:  38% 1.31G/3.44G [04:59<11:18, 3.13MB/s]
#
#
# diffusion_pytorch_model.bin:  38% 1.31G/3.44G [04:59<11:30, 3.08MB/s]
#
#
# diffusion_pytorch_model.bin:  38% 1.31G/3.44G [05:00<11:59, 2.95MB/s]
#
#
# diffusion_pytorch_model.bin:  38% 1.32G/3.44G [05:00<09:33, 3.70MB/s]
#
#
# diffusion_pytorch_model.bin:  38% 1.32G/3.44G [05:00<07:35, 4.66MB/s]
#
#
# diffusion_pytorch_model.bin:  38% 1.32G/3.44G [05:00<06:21, 5.55MB/s]
#
#
# diffusion_pytorch_model.bin:  38% 1.32G/3.44G [05:00<04:23, 8.02MB/s]
#
#
# diffusion_pytorch_model.bin:  39% 1.33G/3.44G [05:01<03:37, 9.69MB/s]
#
#
# diffusion_pytorch_model.bin:  39% 1.33G/3.44G [05:01<03:47, 9.29MB/s]
#
#
# diffusion_pytorch_model.bin:  39% 1.33G/3.44G [05:02<12:04, 2.91MB/s]
#
#
# diffusion_pytorch_model.bin:  39% 1.33G/3.44G [05:03<13:25, 2.62MB/s]
#
#
# diffusion_pytorch_model.bin:  39% 1.33G/3.44G [05:03<11:05, 3.17MB/s]
#
#
# diffusion_pytorch_model.bin:  39% 1.33G/3.44G [05:03<09:31, 3.68MB/s]
#
#
# diffusion_pytorch_model.bin:  39% 1.33G/3.44G [05:04<08:24, 4.18MB/s]
#
#
# diffusion_pytorch_model.bin:  39% 1.34G/3.44G [05:04<07:18, 4.79MB/s]
#
#
# diffusion_pytorch_model.bin:  39% 1.34G/3.44G [05:04<04:59, 7.02MB/s]
#
#
# diffusion_pytorch_model.bin:  39% 1.34G/3.44G [05:04<04:39, 7.52MB/s]
#
#
# diffusion_pytorch_model.bin:  39% 1.34G/3.44G [05:04<03:43, 9.37MB/s]
#
#
# diffusion_pytorch_model.bin:  39% 1.34G/3.44G [05:06<11:45, 2.97MB/s]
#
#
# diffusion_pytorch_model.bin:  39% 1.35G/3.44G [05:07<12:59, 2.68MB/s]
#
#
# diffusion_pytorch_model.bin:  39% 1.35G/3.44G [05:07<13:01, 2.68MB/s]
#
#
# diffusion_pytorch_model.bin:  39% 1.35G/3.44G [05:07<10:45, 3.24MB/s]
#
#
# diffusion_pytorch_model.bin:  39% 1.35G/3.44G [05:07<07:54, 4.40MB/s]
#
#
# diffusion_pytorch_model.bin:  39% 1.35G/3.44G [05:07<06:38, 5.24MB/s]
#
#
# diffusion_pytorch_model.bin:  39% 1.35G/3.44G [05:08<04:43, 7.34MB/s]
#
#
# diffusion_pytorch_model.bin:  39% 1.36G/3.44G [05:08<04:26, 7.81MB/s]
#
#
# diffusion_pytorch_model.bin:  40% 1.36G/3.44G [05:08<03:38, 9.50MB/s]
#
#
# diffusion_pytorch_model.bin:  40% 1.36G/3.44G [05:10<11:39, 2.97MB/s]
#
#
# diffusion_pytorch_model.bin:  40% 1.36G/3.44G [05:10<12:49, 2.70MB/s]
#
#
# diffusion_pytorch_model.bin:  40% 1.36G/3.44G [05:10<11:40, 2.97MB/s]
#
#
# diffusion_pytorch_model.bin:  40% 1.36G/3.44G [05:11<09:59, 3.46MB/s]
#
#
# diffusion_pytorch_model.bin:  40% 1.37G/3.44G [05:11<07:50, 4.40MB/s]
#
#
# diffusion_pytorch_model.bin:  40% 1.37G/3.44G [05:11<07:01, 4.92MB/s]
#
#
# diffusion_pytorch_model.bin:  40% 1.37G/3.44G [05:11<05:52, 5.87MB/s]
#
#
# diffusion_pytorch_model.bin:  40% 1.37G/3.44G [05:11<04:14, 8.10MB/s]
#
#
# diffusion_pytorch_model.bin:  40% 1.38G/3.44G [05:12<03:29, 9.84MB/s]
#
#
# diffusion_pytorch_model.bin:  40% 1.38G/3.44G [05:13<10:57, 3.14MB/s]
#
#
# diffusion_pytorch_model.bin:  40% 1.38G/3.44G [05:14<11:49, 2.90MB/s]
#
#
# diffusion_pytorch_model.bin:  40% 1.38G/3.44G [05:14<10:17, 3.34MB/s]
#
#
# diffusion_pytorch_model.bin:  40% 1.38G/3.44G [05:14<10:09, 3.38MB/s]
#
#
# diffusion_pytorch_model.bin:  40% 1.38G/3.44G [05:15<08:07, 4.22MB/s]
#
#
# diffusion_pytorch_model.bin:  40% 1.39G/3.44G [05:15<05:05, 6.71MB/s]
#
#
# diffusion_pytorch_model.bin:  40% 1.39G/3.44G [05:15<04:43, 7.22MB/s]
#
#
# diffusion_pytorch_model.bin:  40% 1.39G/3.44G [05:15<03:45, 9.08MB/s]
#
#
# diffusion_pytorch_model.bin:  40% 1.39G/3.44G [05:17<12:08, 2.81MB/s]
#
#
# diffusion_pytorch_model.bin:  41% 1.39G/3.44G [05:17<11:48, 2.89MB/s]
#
#
# diffusion_pytorch_model.bin:  41% 1.39G/3.44G [05:18<09:32, 3.57MB/s]
#
#
# diffusion_pytorch_model.bin:  41% 1.40G/3.44G [05:18<09:31, 3.57MB/s]
#
#
# diffusion_pytorch_model.bin:  41% 1.40G/3.44G [05:18<07:38, 4.44MB/s]
#
#
# diffusion_pytorch_model.bin:  41% 1.40G/3.44G [05:18<06:28, 5.25MB/s]
#
#
# diffusion_pytorch_model.bin:  41% 1.40G/3.44G [05:19<05:19, 6.37MB/s]
#
#
# diffusion_pytorch_model.bin:  41% 1.41G/3.44G [05:19<03:51, 8.77MB/s]
#
#
# diffusion_pytorch_model.bin:  41% 1.41G/3.44G [05:20<07:40, 4.41MB/s]
#
#
# diffusion_pytorch_model.bin:  41% 1.41G/3.44G [05:21<11:47, 2.87MB/s]
#
#
# diffusion_pytorch_model.bin:  41% 1.41G/3.44G [05:21<11:56, 2.83MB/s]
#
#
# diffusion_pytorch_model.bin:  41% 1.41G/3.44G [05:21<09:44, 3.47MB/s]
#
#
# diffusion_pytorch_model.bin:  41% 1.41G/3.44G [05:22<09:46, 3.45MB/s]
#
#
# diffusion_pytorch_model.bin:  41% 1.41G/3.44G [05:22<07:40, 4.39MB/s]
#
#
# diffusion_pytorch_model.bin:  41% 1.42G/3.44G [05:22<04:46, 7.05MB/s]
#
#
# diffusion_pytorch_model.bin:  41% 1.42G/3.44G [05:22<04:29, 7.48MB/s]
#
#
# diffusion_pytorch_model.bin:  41% 1.42G/3.44G [05:23<03:36, 9.29MB/s]
#
#
# diffusion_pytorch_model.bin:  41% 1.42G/3.44G [05:24<11:59, 2.80MB/s]
#
#
# diffusion_pytorch_model.bin:  41% 1.43G/3.44G [05:25<11:20, 2.96MB/s]
#
#
# diffusion_pytorch_model.bin:  41% 1.43G/3.44G [05:25<11:05, 3.03MB/s]
#
#
# diffusion_pytorch_model.bin:  42% 1.43G/3.44G [05:25<09:24, 3.56MB/s]
#
#
# diffusion_pytorch_model.bin:  42% 1.43G/3.44G [05:25<07:21, 4.55MB/s]
#
#
# diffusion_pytorch_model.bin:  42% 1.43G/3.44G [05:26<06:27, 5.18MB/s]
#
#
# diffusion_pytorch_model.bin:  42% 1.43G/3.44G [05:26<04:29, 7.45MB/s]
#
#
# diffusion_pytorch_model.bin:  42% 1.44G/3.44G [05:26<03:41, 9.03MB/s]
#
#
# diffusion_pytorch_model.bin:  42% 1.44G/3.44G [05:27<08:11, 4.07MB/s]
#
#
# diffusion_pytorch_model.bin:  42% 1.44G/3.44G [05:28<11:48, 2.82MB/s]
#
#
# diffusion_pytorch_model.bin:  42% 1.44G/3.44G [05:28<11:54, 2.80MB/s]
#
#
# diffusion_pytorch_model.bin:  42% 1.44G/3.44G [05:29<09:54, 3.36MB/s]
#
#
# diffusion_pytorch_model.bin:  42% 1.44G/3.44G [05:29<09:47, 3.39MB/s]
#
#
# diffusion_pytorch_model.bin:  42% 1.45G/3.44G [05:29<07:47, 4.27MB/s]
#
#
# diffusion_pytorch_model.bin:  42% 1.45G/3.44G [05:30<04:50, 6.85MB/s]
#
#
# diffusion_pytorch_model.bin:  42% 1.45G/3.44G [05:30<04:32, 7.29MB/s]
#
#
# diffusion_pytorch_model.bin:  42% 1.46G/3.44G [05:30<03:35, 9.19MB/s]
#
#
# diffusion_pytorch_model.bin:  42% 1.46G/3.44G [05:32<10:50, 3.05MB/s]
#
#
# diffusion_pytorch_model.bin:  42% 1.46G/3.44G [05:32<11:56, 2.77MB/s]
#
#
# diffusion_pytorch_model.bin:  42% 1.46G/3.44G [05:32<09:40, 3.41MB/s]
#
#
# diffusion_pytorch_model.bin:  42% 1.46G/3.44G [05:33<09:38, 3.42MB/s]
#
#
# diffusion_pytorch_model.bin:  43% 1.46G/3.44G [05:33<07:46, 4.23MB/s]
#
#
# diffusion_pytorch_model.bin:  43% 1.47G/3.44G [05:33<04:57, 6.63MB/s]
#
#
# diffusion_pytorch_model.bin:  43% 1.47G/3.44G [05:33<03:54, 8.38MB/s]
#
#
# diffusion_pytorch_model.bin:  43% 1.47G/3.44G [05:34<03:50, 8.54MB/s]
#
#
# diffusion_pytorch_model.bin:  43% 1.47G/3.44G [05:35<11:21, 2.89MB/s]
#
#
# diffusion_pytorch_model.bin:  43% 1.47G/3.44G [05:36<11:07, 2.94MB/s]
#
#
# diffusion_pytorch_model.bin:  43% 1.47G/3.44G [05:36<11:10, 2.93MB/s]
#
#
# diffusion_pytorch_model.bin:  43% 1.47G/3.44G [05:36<11:32, 2.84MB/s]
#
#
# diffusion_pytorch_model.bin:  43% 1.48G/3.44G [05:36<10:28, 3.12MB/s]
#
#
# diffusion_pytorch_model.bin:  43% 1.48G/3.44G [05:36<07:11, 4.55MB/s]
#
#
# diffusion_pytorch_model.bin:  43% 1.48G/3.44G [05:37<06:00, 5.43MB/s]
#
#
# diffusion_pytorch_model.bin:  43% 1.48G/3.44G [05:37<05:10, 6.31MB/s]
#
#
# diffusion_pytorch_model.bin:  43% 1.49G/3.44G [05:37<03:31, 9.23MB/s]
#
#
# diffusion_pytorch_model.bin:  43% 1.49G/3.44G [05:37<03:32, 9.17MB/s]
#
#
# diffusion_pytorch_model.bin:  43% 1.49G/3.44G [05:38<08:02, 4.04MB/s]
#
#
# diffusion_pytorch_model.bin:  43% 1.49G/3.44G [05:39<12:34, 2.58MB/s]
#
#
# diffusion_pytorch_model.bin:  43% 1.49G/3.44G [05:39<12:42, 2.56MB/s]
#
#
# diffusion_pytorch_model.bin:  43% 1.49G/3.44G [05:40<10:00, 3.25MB/s]
#
#
# diffusion_pytorch_model.bin:  43% 1.49G/3.44G [05:40<08:36, 3.77MB/s]
#
#
# diffusion_pytorch_model.bin:  43% 1.49G/3.44G [05:40<07:18, 4.43MB/s]
#
#
# diffusion_pytorch_model.bin:  43% 1.50G/3.44G [05:40<06:24, 5.05MB/s]
#
#
# diffusion_pytorch_model.bin:  44% 1.50G/3.44G [05:41<05:21, 6.05MB/s]
#
#
# diffusion_pytorch_model.bin:  44% 1.50G/3.44G [05:41<03:52, 8.33MB/s]
#
#
# diffusion_pytorch_model.bin:  44% 1.50G/3.44G [05:41<03:12, 10.0MB/s]
#
#
# diffusion_pytorch_model.bin:  44% 1.50G/3.44G [05:43<11:27, 2.81MB/s]
#
#
# diffusion_pytorch_model.bin:  44% 1.51G/3.44G [05:43<11:08, 2.89MB/s]
#
#
# diffusion_pytorch_model.bin:  44% 1.51G/3.44G [05:43<11:06, 2.90MB/s]
#
#
# diffusion_pytorch_model.bin:  44% 1.51G/3.44G [05:43<09:52, 3.26MB/s]
#
#
# diffusion_pytorch_model.bin:  44% 1.51G/3.44G [05:44<07:10, 4.48MB/s]
#
#
# diffusion_pytorch_model.bin:  44% 1.51G/3.44G [05:44<06:03, 5.30MB/s]
#
#
# diffusion_pytorch_model.bin:  44% 1.51G/3.44G [05:44<05:15, 6.11MB/s]
#
#
# diffusion_pytorch_model.bin:  44% 1.52G/3.44G [05:44<03:46, 8.48MB/s]
#
#
# diffusion_pytorch_model.bin:  44% 1.52G/3.44G [05:45<03:46, 8.47MB/s]
#
#
# diffusion_pytorch_model.bin:  44% 1.52G/3.44G [05:46<07:41, 4.16MB/s]
#
#
# diffusion_pytorch_model.bin:  44% 1.52G/3.44G [05:46<10:40, 2.99MB/s]
#
#
# diffusion_pytorch_model.bin:  44% 1.52G/3.44G [05:47<12:40, 2.52MB/s]
#
#
# diffusion_pytorch_model.bin:  44% 1.52G/3.44G [05:47<13:12, 2.42MB/s]
#
#
# diffusion_pytorch_model.bin:  44% 1.52G/3.44G [05:47<08:33, 3.72MB/s]
#
#
# diffusion_pytorch_model.bin:  44% 1.53G/3.44G [05:48<07:04, 4.50MB/s]
#
#
# diffusion_pytorch_model.bin:  44% 1.53G/3.44G [05:48<05:55, 5.37MB/s]
#
#
# diffusion_pytorch_model.bin:  45% 1.53G/3.44G [05:48<04:06, 7.73MB/s]
#
#
# diffusion_pytorch_model.bin:  45% 1.54G/3.44G [05:48<03:24, 9.30MB/s]
#
#
# diffusion_pytorch_model.bin:  45% 1.54G/3.44G [05:50<10:10, 3.11MB/s]
#
#
# diffusion_pytorch_model.bin:  45% 1.54G/3.44G [05:50<11:17, 2.81MB/s]
#
#
# diffusion_pytorch_model.bin:  45% 1.54G/3.44G [05:51<09:04, 3.49MB/s]
#
#
# diffusion_pytorch_model.bin:  45% 1.54G/3.44G [05:51<09:00, 3.51MB/s]
#
#
# diffusion_pytorch_model.bin:  45% 1.54G/3.44G [05:51<07:02, 4.49MB/s]
#
#
# diffusion_pytorch_model.bin:  45% 1.55G/3.44G [05:52<04:35, 6.87MB/s]
#
#
# diffusion_pytorch_model.bin:  45% 1.55G/3.44G [05:52<03:42, 8.48MB/s]
#
#
# diffusion_pytorch_model.bin:  45% 1.55G/3.44G [05:52<03:46, 8.33MB/s]
#
#
# diffusion_pytorch_model.bin:  45% 1.55G/3.44G [05:54<12:18, 2.55MB/s]
#
#
# diffusion_pytorch_model.bin:  45% 1.55G/3.44G [05:54<11:56, 2.63MB/s]
#
#
# diffusion_pytorch_model.bin:  45% 1.55G/3.44G [05:54<09:20, 3.36MB/s]
#
#
# diffusion_pytorch_model.bin:  45% 1.56G/3.44G [05:55<09:10, 3.42MB/s]
#
#
# diffusion_pytorch_model.bin:  45% 1.56G/3.44G [05:55<07:05, 4.42MB/s]
#
#
# diffusion_pytorch_model.bin:  45% 1.56G/3.44G [05:55<04:34, 6.84MB/s]
#
#
# diffusion_pytorch_model.bin:  46% 1.57G/3.44G [05:55<03:41, 8.45MB/s]
#
#
# diffusion_pytorch_model.bin:  46% 1.57G/3.44G [05:56<03:43, 8.37MB/s]
#
#
# diffusion_pytorch_model.bin:  46% 1.57G/3.44G [05:58<12:08, 2.57MB/s]
#
#
# diffusion_pytorch_model.bin:  46% 1.57G/3.44G [05:58<13:03, 2.39MB/s]
#
#
# diffusion_pytorch_model.bin:  46% 1.57G/3.44G [05:58<12:55, 2.41MB/s]
#
#
# diffusion_pytorch_model.bin:  46% 1.57G/3.44G [05:59<08:52, 3.50MB/s]
#
#
# diffusion_pytorch_model.bin:  46% 1.57G/3.44G [05:59<07:18, 4.25MB/s]
#
#
# diffusion_pytorch_model.bin:  46% 1.58G/3.44G [05:59<06:05, 5.09MB/s]
#
#
# diffusion_pytorch_model.bin:  46% 1.58G/3.44G [05:59<04:08, 7.49MB/s]
#
#
# diffusion_pytorch_model.bin:  46% 1.58G/3.44G [06:00<03:25, 9.03MB/s]
#
#
# diffusion_pytorch_model.bin:  46% 1.58G/3.44G [06:01<10:41, 2.89MB/s]
#
#
# diffusion_pytorch_model.bin:  46% 1.59G/3.44G [06:02<10:24, 2.97MB/s]
#
#
# diffusion_pytorch_model.bin:  46% 1.59G/3.44G [06:02<10:23, 2.97MB/s]
#
#
# diffusion_pytorch_model.bin:  46% 1.59G/3.44G [06:02<08:52, 3.47MB/s]
#
#
# diffusion_pytorch_model.bin:  46% 1.59G/3.44G [06:02<07:42, 4.00MB/s]
#
#
# diffusion_pytorch_model.bin:  46% 1.59G/3.44G [06:02<06:49, 4.51MB/s]
#
#
# diffusion_pytorch_model.bin:  46% 1.59G/3.44G [06:03<04:08, 7.43MB/s]
#
#
# diffusion_pytorch_model.bin:  46% 1.60G/3.44G [06:03<03:19, 9.22MB/s]
#
#
# diffusion_pytorch_model.bin:  47% 1.60G/3.44G [06:03<03:16, 9.35MB/s]
#
#
# diffusion_pytorch_model.bin:  47% 1.60G/3.44G [06:05<10:24, 2.94MB/s]
#
#
# diffusion_pytorch_model.bin:  47% 1.60G/3.44G [06:05<11:28, 2.67MB/s]
#
#
# diffusion_pytorch_model.bin:  47% 1.60G/3.44G [06:05<09:10, 3.33MB/s]
#
#
# diffusion_pytorch_model.bin:  47% 1.60G/3.44G [06:06<09:11, 3.32MB/s]
#
#
# diffusion_pytorch_model.bin:  47% 1.61G/3.44G [06:06<07:20, 4.16MB/s]
#
#
# diffusion_pytorch_model.bin:  47% 1.61G/3.44G [06:06<04:35, 6.64MB/s]
#
#
# diffusion_pytorch_model.bin:  47% 1.61G/3.44G [06:07<04:05, 7.44MB/s]
#
#
# diffusion_pytorch_model.bin:  47% 1.62G/3.44G [06:07<03:21, 9.03MB/s]
#
#
# diffusion_pytorch_model.bin:  47% 1.62G/3.44G [06:09<10:44, 2.83MB/s]
#
#
# diffusion_pytorch_model.bin:  47% 1.62G/3.44G [06:09<10:09, 2.99MB/s]
#
#
# diffusion_pytorch_model.bin:  47% 1.62G/3.44G [06:09<10:03, 3.02MB/s]
#
#
# diffusion_pytorch_model.bin:  47% 1.62G/3.44G [06:09<08:37, 3.52MB/s]
#
#
# diffusion_pytorch_model.bin:  47% 1.62G/3.44G [06:10<06:47, 4.46MB/s]
#
#
# diffusion_pytorch_model.bin:  47% 1.62G/3.44G [06:10<05:44, 5.27MB/s]
#
#
# diffusion_pytorch_model.bin:  47% 1.63G/3.44G [06:10<04:05, 7.39MB/s]
#
#
# diffusion_pytorch_model.bin:  47% 1.63G/3.44G [06:10<03:51, 7.80MB/s]
#
#
# diffusion_pytorch_model.bin:  47% 1.63G/3.44G [06:10<03:05, 9.73MB/s]
#
#
# diffusion_pytorch_model.bin:  47% 1.63G/3.44G [06:12<10:53, 2.76MB/s]
#
#
# diffusion_pytorch_model.bin:  48% 1.63G/3.44G [06:13<10:33, 2.85MB/s]
#
#
# diffusion_pytorch_model.bin:  48% 1.63G/3.44G [06:13<09:17, 3.24MB/s]
#
#
# diffusion_pytorch_model.bin:  48% 1.64G/3.44G [06:13<09:05, 3.30MB/s]
#
#
# diffusion_pytorch_model.bin:  48% 1.64G/3.44G [06:13<05:50, 5.13MB/s]
#
#
# diffusion_pytorch_model.bin:  48% 1.64G/3.44G [06:14<05:06, 5.86MB/s]
#
#
# diffusion_pytorch_model.bin:  48% 1.65G/3.44G [06:14<03:34, 8.36MB/s]
#
#
# diffusion_pytorch_model.bin:  48% 1.65G/3.44G [06:14<03:34, 8.35MB/s]
#
#
# diffusion_pytorch_model.bin:  48% 1.65G/3.44G [06:16<09:39, 3.09MB/s]
#
#
# diffusion_pytorch_model.bin:  48% 1.65G/3.44G [06:16<12:04, 2.47MB/s]
#
#
# diffusion_pytorch_model.bin:  48% 1.65G/3.44G [06:16<12:00, 2.48MB/s]
#
#
# diffusion_pytorch_model.bin:  48% 1.65G/3.44G [06:17<07:56, 3.74MB/s]
#
#
# diffusion_pytorch_model.bin:  48% 1.65G/3.44G [06:17<06:38, 4.48MB/s]
#
#
# diffusion_pytorch_model.bin:  48% 1.66G/3.44G [06:17<04:25, 6.71MB/s]
#
#
# diffusion_pytorch_model.bin:  48% 1.66G/3.44G [06:18<03:32, 8.36MB/s]
#
#
# diffusion_pytorch_model.bin:  48% 1.66G/3.44G [06:18<03:27, 8.57MB/s]
#
#
# diffusion_pytorch_model.bin:  48% 1.66G/3.44G [06:20<11:11, 2.64MB/s]
#
#
# diffusion_pytorch_model.bin:  48% 1.67G/3.44G [06:20<10:35, 2.79MB/s]
#
#
# diffusion_pytorch_model.bin:  48% 1.67G/3.44G [06:20<10:23, 2.84MB/s]
#
#
# diffusion_pytorch_model.bin:  48% 1.67G/3.44G [06:20<08:54, 3.31MB/s]
#
#
# diffusion_pytorch_model.bin:  49% 1.67G/3.44G [06:21<06:47, 4.34MB/s]
#
#
# diffusion_pytorch_model.bin:  49% 1.67G/3.44G [06:21<05:46, 5.10MB/s]
#
#
# diffusion_pytorch_model.bin:  49% 1.67G/3.44G [06:21<04:03, 7.25MB/s]
#
#
# diffusion_pytorch_model.bin:  49% 1.68G/3.44G [06:21<03:48, 7.71MB/s]
#
#
# diffusion_pytorch_model.bin:  49% 1.68G/3.44G [06:21<03:03, 9.57MB/s]
#
#
# diffusion_pytorch_model.bin:  49% 1.68G/3.44G [06:23<09:59, 2.93MB/s]
#
#
# diffusion_pytorch_model.bin:  49% 1.68G/3.44G [06:24<10:42, 2.74MB/s]
#
#
# diffusion_pytorch_model.bin:  49% 1.68G/3.44G [06:24<09:00, 3.25MB/s]
#
#
# diffusion_pytorch_model.bin:  49% 1.68G/3.44G [06:24<08:50, 3.30MB/s]
#
#
# diffusion_pytorch_model.bin:  49% 1.69G/3.44G [06:24<07:02, 4.15MB/s]
#
#
# diffusion_pytorch_model.bin:  49% 1.69G/3.44G [06:25<04:28, 6.51MB/s]
#
#
# diffusion_pytorch_model.bin:  49% 1.69G/3.44G [06:25<03:28, 8.36MB/s]
#
#
# diffusion_pytorch_model.bin:  49% 1.70G/3.44G [06:25<03:25, 8.46MB/s]
#
#
# diffusion_pytorch_model.bin:  49% 1.70G/3.44G [06:26<09:10, 3.17MB/s]
#
#
# diffusion_pytorch_model.bin:  49% 1.70G/3.44G [06:27<10:17, 2.82MB/s]
#
#
# diffusion_pytorch_model.bin:  49% 1.70G/3.44G [06:27<10:25, 2.78MB/s]
#
#
# diffusion_pytorch_model.bin:  49% 1.70G/3.44G [06:27<08:38, 3.35MB/s]
#
#
# diffusion_pytorch_model.bin:  49% 1.70G/3.44G [06:28<08:34, 3.38MB/s]
#
#
# diffusion_pytorch_model.bin:  50% 1.70G/3.44G [06:28<06:37, 4.37MB/s]
#
#
# diffusion_pytorch_model.bin:  50% 1.71G/3.44G [06:28<04:07, 7.01MB/s]
#
#
# diffusion_pytorch_model.bin:  50% 1.71G/3.44G [06:29<03:17, 8.77MB/s]
#
#
# diffusion_pytorch_model.bin:  50% 1.71G/3.44G [06:29<03:14, 8.89MB/s]
#
#
# diffusion_pytorch_model.bin:  50% 1.71G/3.44G [06:30<09:54, 2.90MB/s]
#
#
# diffusion_pytorch_model.bin:  50% 1.71G/3.44G [06:31<09:57, 2.89MB/s]
#
#
# diffusion_pytorch_model.bin:  50% 1.71G/3.44G [06:31<09:45, 2.95MB/s]
#
#
# diffusion_pytorch_model.bin:  50% 1.71G/3.44G [06:31<10:04, 2.85MB/s]
#
#
# diffusion_pytorch_model.bin:  50% 1.72G/3.44G [06:31<08:13, 3.49MB/s]
#
#
# diffusion_pytorch_model.bin:  50% 1.72G/3.44G [06:32<07:39, 3.74MB/s]
#
#
# diffusion_pytorch_model.bin:  50% 1.72G/3.44G [06:32<05:49, 4.92MB/s]
#
#
# diffusion_pytorch_model.bin:  50% 1.72G/3.44G [06:32<04:36, 6.21MB/s]
#
#
# diffusion_pytorch_model.bin:  50% 1.73G/3.44G [06:32<03:11, 8.95MB/s]
#
#
# diffusion_pytorch_model.bin:  50% 1.73G/3.44G [06:33<03:20, 8.52MB/s]
#
#
# diffusion_pytorch_model.bin:  50% 1.73G/3.44G [06:34<10:43, 2.66MB/s]
#
#
# diffusion_pytorch_model.bin:  50% 1.73G/3.44G [06:34<10:31, 2.71MB/s]
#
#
# diffusion_pytorch_model.bin:  50% 1.73G/3.44G [06:35<10:37, 2.68MB/s]
#
#
# diffusion_pytorch_model.bin:  50% 1.73G/3.44G [06:35<08:46, 3.24MB/s]
#
#
# diffusion_pytorch_model.bin:  50% 1.73G/3.44G [06:35<08:34, 3.31MB/s]
#
#
# diffusion_pytorch_model.bin:  50% 1.73G/3.44G [06:36<06:32, 4.35MB/s]
#
#
# diffusion_pytorch_model.bin:  51% 1.74G/3.44G [06:36<03:58, 7.13MB/s]
#
#
# diffusion_pytorch_model.bin:  51% 1.74G/3.44G [06:36<03:44, 7.56MB/s]
#
#
# diffusion_pytorch_model.bin:  51% 1.74G/3.44G [06:36<03:02, 9.30MB/s]
#
#
# diffusion_pytorch_model.bin:  51% 1.74G/3.44G [06:38<09:17, 3.04MB/s]
#
#
# diffusion_pytorch_model.bin:  51% 1.75G/3.44G [06:38<09:20, 3.02MB/s]
#
#
# diffusion_pytorch_model.bin:  51% 1.75G/3.44G [06:38<09:09, 3.08MB/s]
#
#
# diffusion_pytorch_model.bin:  51% 1.75G/3.44G [06:39<09:28, 2.98MB/s]
#
#
# diffusion_pytorch_model.bin:  51% 1.75G/3.44G [06:39<08:22, 3.36MB/s]
#
#
# diffusion_pytorch_model.bin:  51% 1.75G/3.44G [06:39<06:14, 4.51MB/s]
#
#
# diffusion_pytorch_model.bin:  51% 1.75G/3.44G [06:39<05:11, 5.42MB/s]
#
#
# diffusion_pytorch_model.bin:  51% 1.75G/3.44G [06:39<03:38, 7.72MB/s]
#
#
# diffusion_pytorch_model.bin:  51% 1.76G/3.44G [06:40<02:54, 9.62MB/s]
#
#
# diffusion_pytorch_model.bin:  51% 1.76G/3.44G [06:40<03:01, 9.25MB/s]
#
#
# diffusion_pytorch_model.bin:  51% 1.76G/3.44G [06:41<10:00, 2.80MB/s]
#
#
# diffusion_pytorch_model.bin:  51% 1.76G/3.44G [06:42<10:04, 2.78MB/s]
#
#
# diffusion_pytorch_model.bin:  51% 1.76G/3.44G [06:42<09:50, 2.84MB/s]
#
#
# diffusion_pytorch_model.bin:  51% 1.76G/3.44G [06:42<10:10, 2.75MB/s]
#
#
# diffusion_pytorch_model.bin:  51% 1.76G/3.44G [06:42<08:32, 3.27MB/s]
#
#
# diffusion_pytorch_model.bin:  51% 1.77G/3.44G [06:43<06:10, 4.51MB/s]
#
#
# diffusion_pytorch_model.bin:  51% 1.77G/3.44G [06:43<05:20, 5.22MB/s]
#
#
# diffusion_pytorch_model.bin:  51% 1.77G/3.44G [06:43<03:40, 7.57MB/s]
#
#
# diffusion_pytorch_model.bin:  52% 1.77G/3.44G [06:43<03:29, 7.94MB/s]
#
#
# diffusion_pytorch_model.bin:  52% 1.78G/3.44G [06:43<02:50, 9.78MB/s]
#
#
# diffusion_pytorch_model.bin:  52% 1.78G/3.44G [06:45<09:16, 2.99MB/s]
#
#
# diffusion_pytorch_model.bin:  52% 1.78G/3.44G [06:46<10:15, 2.70MB/s]
#
#
# diffusion_pytorch_model.bin:  52% 1.78G/3.44G [06:46<08:40, 3.19MB/s]
#
#
# diffusion_pytorch_model.bin:  52% 1.78G/3.44G [06:46<07:28, 3.70MB/s]
#
#
# diffusion_pytorch_model.bin:  52% 1.78G/3.44G [06:46<06:30, 4.24MB/s]
#
#
# diffusion_pytorch_model.bin:  52% 1.78G/3.44G [06:46<05:44, 4.80MB/s]
#
#
# diffusion_pytorch_model.bin:  52% 1.78G/3.44G [06:47<04:47, 5.76MB/s]
#
#
# diffusion_pytorch_model.bin:  52% 1.79G/3.44G [06:47<03:22, 8.14MB/s]
#
#
# diffusion_pytorch_model.bin:  52% 1.79G/3.44G [06:47<02:47, 9.84MB/s]
#
#
# diffusion_pytorch_model.bin:  52% 1.79G/3.44G [06:49<09:02, 3.03MB/s]
#
#
# diffusion_pytorch_model.bin:  52% 1.79G/3.44G [06:49<09:43, 2.82MB/s]
#
#
# diffusion_pytorch_model.bin:  52% 1.79G/3.44G [06:49<08:23, 3.26MB/s]
#
#
# diffusion_pytorch_model.bin:  52% 1.80G/3.44G [06:50<07:23, 3.70MB/s]
#
#
# diffusion_pytorch_model.bin:  52% 1.80G/3.44G [06:50<06:21, 4.30MB/s]
#
#
# diffusion_pytorch_model.bin:  52% 1.80G/3.44G [06:50<05:34, 4.89MB/s]
#
#
# diffusion_pytorch_model.bin:  52% 1.80G/3.44G [06:50<04:35, 5.95MB/s]
#
#
# diffusion_pytorch_model.bin:  53% 1.81G/3.44G [06:51<03:06, 8.77MB/s]
#
#
# diffusion_pytorch_model.bin:  53% 1.81G/3.44G [06:51<03:07, 8.68MB/s]
#
#
# diffusion_pytorch_model.bin:  53% 1.81G/3.44G [06:52<07:14, 3.75MB/s]
#
#
# diffusion_pytorch_model.bin:  53% 1.81G/3.44G [06:53<11:00, 2.47MB/s]
#
#
# diffusion_pytorch_model.bin:  53% 1.81G/3.44G [06:53<10:23, 2.61MB/s]
#
#
# diffusion_pytorch_model.bin:  53% 1.81G/3.44G [06:53<09:51, 2.75MB/s]
#
#
# diffusion_pytorch_model.bin:  53% 1.81G/3.44G [06:53<07:55, 3.42MB/s]
#
#
# diffusion_pytorch_model.bin:  53% 1.81G/3.44G [06:54<05:56, 4.55MB/s]
#
#
# diffusion_pytorch_model.bin:  53% 1.82G/3.44G [06:54<05:08, 5.26MB/s]
#
#
# diffusion_pytorch_model.bin:  53% 1.82G/3.44G [06:54<03:35, 7.52MB/s]
#
#
# diffusion_pytorch_model.bin:  53% 1.82G/3.44G [06:54<02:54, 9.24MB/s]
#
#
# diffusion_pytorch_model.bin:  53% 1.82G/3.44G [06:55<05:37, 4.78MB/s]
#
#
# diffusion_pytorch_model.bin:  53% 1.82G/3.44G [06:56<08:43, 3.08MB/s]
#
#
# diffusion_pytorch_model.bin:  53% 1.83G/3.44G [06:56<08:43, 3.08MB/s]
#
#
# diffusion_pytorch_model.bin:  53% 1.83G/3.44G [06:57<08:40, 3.10MB/s]
#
#
# diffusion_pytorch_model.bin:  53% 1.83G/3.44G [06:57<07:15, 3.70MB/s]
#
#
# diffusion_pytorch_model.bin:  53% 1.83G/3.44G [06:57<05:42, 4.70MB/s]
#
#
# diffusion_pytorch_model.bin:  53% 1.83G/3.44G [06:57<04:50, 5.53MB/s]
#
#
# diffusion_pytorch_model.bin:  53% 1.83G/3.44G [06:58<03:30, 7.63MB/s]
#
#
# diffusion_pytorch_model.bin:  53% 1.84G/3.44G [06:58<02:48, 9.51MB/s]
#
#
# diffusion_pytorch_model.bin:  53% 1.84G/3.44G [06:58<02:55, 9.11MB/s]
#
#
# diffusion_pytorch_model.bin:  54% 1.84G/3.44G [07:00<09:33, 2.78MB/s]
#
#
# diffusion_pytorch_model.bin:  54% 1.84G/3.44G [07:00<09:36, 2.77MB/s]
#
#
# diffusion_pytorch_model.bin:  54% 1.84G/3.44G [07:00<09:24, 2.83MB/s]
#
#
# diffusion_pytorch_model.bin:  54% 1.84G/3.44G [07:00<09:44, 2.73MB/s]
#
#
# diffusion_pytorch_model.bin:  54% 1.84G/3.44G [07:00<07:43, 3.44MB/s]
#
#
# diffusion_pytorch_model.bin:  54% 1.85G/3.44G [07:01<05:48, 4.57MB/s]
#
#
# diffusion_pytorch_model.bin:  54% 1.85G/3.44G [07:01<04:50, 5.47MB/s]
#
#
# diffusion_pytorch_model.bin:  54% 1.85G/3.44G [07:01<04:08, 6.39MB/s]
#
#
# diffusion_pytorch_model.bin:  54% 1.85G/3.44G [07:01<02:50, 9.31MB/s]
#
#
# diffusion_pytorch_model.bin:  54% 1.86G/3.44G [07:02<02:56, 8.99MB/s]
#
#
# diffusion_pytorch_model.bin:  54% 1.86G/3.44G [07:03<06:45, 3.90MB/s]
#
#
# diffusion_pytorch_model.bin:  54% 1.86G/3.44G [07:03<10:31, 2.50MB/s]
#
#
# diffusion_pytorch_model.bin:  54% 1.86G/3.44G [07:04<10:08, 2.60MB/s]
#
#
# diffusion_pytorch_model.bin:  54% 1.86G/3.44G [07:04<09:45, 2.70MB/s]
#
#
# diffusion_pytorch_model.bin:  54% 1.86G/3.44G [07:04<06:59, 3.76MB/s]
#
#
# diffusion_pytorch_model.bin:  54% 1.86G/3.44G [07:05<05:44, 4.57MB/s]
#
#
# diffusion_pytorch_model.bin:  54% 1.87G/3.44G [07:05<03:43, 7.02MB/s]
#
#
# diffusion_pytorch_model.bin:  54% 1.87G/3.44G [07:05<02:55, 8.95MB/s]
#
#
# diffusion_pytorch_model.bin:  54% 1.87G/3.44G [07:05<02:55, 8.93MB/s]
#
#
# diffusion_pytorch_model.bin:  54% 1.87G/3.44G [07:07<09:46, 2.67MB/s]
#
#
# diffusion_pytorch_model.bin:  54% 1.87G/3.44G [07:07<09:31, 2.74MB/s]
#
#
# diffusion_pytorch_model.bin:  54% 1.87G/3.44G [07:07<09:29, 2.75MB/s]
#
#
# diffusion_pytorch_model.bin:  55% 1.88G/3.44G [07:08<07:07, 3.65MB/s]
#
#
# diffusion_pytorch_model.bin:  55% 1.88G/3.44G [07:08<04:55, 5.27MB/s]
#
#
# diffusion_pytorch_model.bin:  55% 1.88G/3.44G [07:08<04:20, 5.99MB/s]
#
#
# diffusion_pytorch_model.bin:  55% 1.88G/3.44G [07:09<03:23, 7.62MB/s]
#
#
# diffusion_pytorch_model.bin:  55% 1.89G/3.44G [07:09<02:46, 9.30MB/s]
#
#
# diffusion_pytorch_model.bin:  55% 1.89G/3.44G [07:11<08:58, 2.88MB/s]
#
#
# diffusion_pytorch_model.bin:  55% 1.89G/3.44G [07:11<08:43, 2.96MB/s]
#
#
# diffusion_pytorch_model.bin:  55% 1.89G/3.44G [07:11<08:40, 2.97MB/s]
#
#
# diffusion_pytorch_model.bin:  55% 1.89G/3.44G [07:11<07:27, 3.46MB/s]
#
#
# diffusion_pytorch_model.bin:  55% 1.89G/3.44G [07:12<05:53, 4.36MB/s]
#
#
# diffusion_pytorch_model.bin:  55% 1.90G/3.44G [07:12<05:01, 5.12MB/s]
#
#
# diffusion_pytorch_model.bin:  55% 1.90G/3.44G [07:12<03:26, 7.46MB/s]
#
#
# diffusion_pytorch_model.bin:  55% 1.90G/3.44G [07:12<02:47, 9.17MB/s]
#
#
# diffusion_pytorch_model.bin:  55% 1.90G/3.44G [07:13<05:25, 4.71MB/s]
#
#
# diffusion_pytorch_model.bin:  55% 1.90G/3.44G [07:14<09:09, 2.79MB/s]
#
#
# diffusion_pytorch_model.bin:  55% 1.91G/3.44G [07:15<08:47, 2.90MB/s]
#
#
# diffusion_pytorch_model.bin:  55% 1.91G/3.44G [07:15<07:02, 3.63MB/s]
#
#
# diffusion_pytorch_model.bin:  56% 1.91G/3.44G [07:15<05:31, 4.61MB/s]
#
#
# diffusion_pytorch_model.bin:  56% 1.91G/3.44G [07:15<04:45, 5.36MB/s]
#
#
# diffusion_pytorch_model.bin:  56% 1.91G/3.44G [07:16<03:27, 7.33MB/s]
#
#
# diffusion_pytorch_model.bin:  56% 1.92G/3.44G [07:16<02:49, 8.99MB/s]
#
#
# diffusion_pytorch_model.bin:  56% 1.92G/3.44G [07:16<02:51, 8.87MB/s]
#
#
# diffusion_pytorch_model.bin:  56% 1.92G/3.44G [07:18<09:03, 2.79MB/s]
#
#
# diffusion_pytorch_model.bin:  56% 1.92G/3.44G [07:18<09:44, 2.59MB/s]
#
#
# diffusion_pytorch_model.bin:  56% 1.92G/3.44G [07:18<07:50, 3.22MB/s]
#
#
# diffusion_pytorch_model.bin:  56% 1.92G/3.44G [07:19<07:40, 3.29MB/s]
#
#
# diffusion_pytorch_model.bin:  56% 1.93G/3.44G [07:19<06:06, 4.13MB/s]
#
#
# diffusion_pytorch_model.bin:  56% 1.93G/3.44G [07:19<03:49, 6.57MB/s]
#
#
# diffusion_pytorch_model.bin:  56% 1.93G/3.44G [07:19<03:02, 8.26MB/s]
#
#
# diffusion_pytorch_model.bin:  56% 1.94G/3.44G [07:20<02:59, 8.38MB/s]
#
#
# diffusion_pytorch_model.bin:  56% 1.94G/3.44G [07:21<07:05, 3.53MB/s]
#
#
# diffusion_pytorch_model.bin:  56% 1.94G/3.44G [07:22<09:25, 2.65MB/s]
#
#
# diffusion_pytorch_model.bin:  56% 1.94G/3.44G [07:22<09:07, 2.74MB/s]
#
#
# diffusion_pytorch_model.bin:  56% 1.94G/3.44G [07:22<08:44, 2.86MB/s]
#
#
# diffusion_pytorch_model.bin:  56% 1.94G/3.44G [07:22<07:06, 3.52MB/s]
#
#
# diffusion_pytorch_model.bin:  56% 1.94G/3.44G [07:22<05:26, 4.58MB/s]
#
#
# diffusion_pytorch_model.bin:  57% 1.94G/3.44G [07:23<04:38, 5.37MB/s]
#
#
# diffusion_pytorch_model.bin:  57% 1.95G/3.44G [07:23<03:16, 7.60MB/s]
#
#
# diffusion_pytorch_model.bin:  57% 1.95G/3.44G [07:23<02:39, 9.35MB/s]
#
#
# diffusion_pytorch_model.bin:  57% 1.95G/3.44G [07:24<05:19, 4.65MB/s]
#
#
# diffusion_pytorch_model.bin:  57% 1.95G/3.44G [07:25<08:09, 3.04MB/s]
#
#
# diffusion_pytorch_model.bin:  57% 1.95G/3.44G [07:25<08:18, 2.98MB/s]
#
#
# diffusion_pytorch_model.bin:  57% 1.95G/3.44G [07:25<08:12, 3.02MB/s]
#
#
# ...
#
#
# diffusion_pytorch_model.bin:  90% 3.08G/3.44G [11:41<01:18, 4.57MB/s]
#
#
# diffusion_pytorch_model.bin:  90% 3.08G/3.44G [11:41<00:49, 7.14MB/s]
#
#
# diffusion_pytorch_model.bin:  90% 3.09G/3.44G [11:41<00:39, 9.01MB/s]
#
#
# diffusion_pytorch_model.bin:  90% 3.09G/3.44G [11:41<00:39, 8.93MB/s]
#
#
# diffusion_pytorch_model.bin:  90% 3.09G/3.44G [11:43<02:12, 2.64MB/s]
#
#
# diffusion_pytorch_model.bin:  90% 3.09G/3.44G [11:43<02:08, 2.71MB/s]
#
#
# diffusion_pytorch_model.bin:  90% 3.09G/3.44G [11:44<02:08, 2.72MB/s]
#
#
# diffusion_pytorch_model.bin:  90% 3.09G/3.44G [11:44<01:40, 3.45MB/s]
#
#
# diffusion_pytorch_model.bin:  90% 3.09G/3.44G [11:44<01:17, 4.47MB/s]
#
#
# diffusion_pytorch_model.bin:  90% 3.10G/3.44G [11:44<01:05, 5.24MB/s]
#
#
# diffusion_pytorch_model.bin:  90% 3.10G/3.44G [11:45<00:44, 7.56MB/s]
#
#
# diffusion_pytorch_model.bin:  90% 3.10G/3.44G [11:45<00:36, 9.32MB/s]
#
#
# diffusion_pytorch_model.bin:  90% 3.10G/3.44G [11:45<00:37, 8.97MB/s]
#
#
# diffusion_pytorch_model.bin:  90% 3.10G/3.44G [11:47<02:14, 2.48MB/s]
#
#
# diffusion_pytorch_model.bin:  90% 3.11G/3.44G [11:47<02:09, 2.57MB/s]
#
#
# diffusion_pytorch_model.bin:  90% 3.11G/3.44G [11:47<01:42, 3.24MB/s]
#
#
# diffusion_pytorch_model.bin:  90% 3.11G/3.44G [11:48<01:39, 3.31MB/s]
#
#
# diffusion_pytorch_model.bin:  90% 3.11G/3.44G [11:48<01:18, 4.16MB/s]
#
#
# diffusion_pytorch_model.bin:  91% 3.11G/3.44G [11:48<00:49, 6.52MB/s]
#
#
# diffusion_pytorch_model.bin:  91% 3.12G/3.44G [11:48<00:38, 8.42MB/s]
#
#
# diffusion_pytorch_model.bin:  91% 3.12G/3.44G [11:49<00:36, 8.80MB/s]
#
#
# diffusion_pytorch_model.bin:  91% 3.12G/3.44G [11:50<01:54, 2.78MB/s]
#
#
# diffusion_pytorch_model.bin:  91% 3.12G/3.44G [11:51<01:50, 2.86MB/s]
#
#
# diffusion_pytorch_model.bin:  91% 3.12G/3.44G [11:51<01:50, 2.87MB/s]
#
#
# diffusion_pytorch_model.bin:  91% 3.12G/3.44G [11:51<01:31, 3.43MB/s]
#
#
# diffusion_pytorch_model.bin:  91% 3.13G/3.44G [11:51<01:09, 4.51MB/s]
#
#
# diffusion_pytorch_model.bin:  91% 3.13G/3.44G [11:52<00:58, 5.31MB/s]
#
#
# diffusion_pytorch_model.bin:  91% 3.13G/3.44G [11:52<00:40, 7.54MB/s]
#
#
# diffusion_pytorch_model.bin:  91% 3.13G/3.44G [11:52<00:32, 9.28MB/s]
#
#
# diffusion_pytorch_model.bin:  91% 3.14G/3.44G [11:53<01:02, 4.85MB/s]
#
#
# diffusion_pytorch_model.bin:  91% 3.14G/3.44G [11:54<01:35, 3.15MB/s]
#
#
# diffusion_pytorch_model.bin:  91% 3.14G/3.44G [11:54<01:37, 3.10MB/s]
#
#
# diffusion_pytorch_model.bin:  91% 3.14G/3.44G [11:54<01:36, 3.11MB/s]
#
#
# diffusion_pytorch_model.bin:  91% 3.14G/3.44G [11:55<01:21, 3.65MB/s]
#
#
# diffusion_pytorch_model.bin:  91% 3.14G/3.44G [11:55<01:04, 4.62MB/s]
#
#
# diffusion_pytorch_model.bin:  91% 3.14G/3.44G [11:55<00:54, 5.40MB/s]
#
#
# diffusion_pytorch_model.bin:  92% 3.15G/3.44G [11:55<00:38, 7.68MB/s]
#
#
# diffusion_pytorch_model.bin:  92% 3.15G/3.44G [11:55<00:29, 9.65MB/s]
#
#
# diffusion_pytorch_model.bin:  92% 3.15G/3.44G [11:56<00:31, 9.23MB/s]
#
#
# diffusion_pytorch_model.bin:  92% 3.15G/3.44G [11:58<01:50, 2.58MB/s]
#
#
# diffusion_pytorch_model.bin:  92% 3.15G/3.44G [11:58<01:42, 2.78MB/s]
#
#
# diffusion_pytorch_model.bin:  92% 3.15G/3.44G [11:58<01:40, 2.83MB/s]
#
#
# diffusion_pytorch_model.bin:  92% 3.16G/3.44G [11:58<01:22, 3.42MB/s]
#
#
# diffusion_pytorch_model.bin:  92% 3.16G/3.44G [11:58<01:02, 4.46MB/s]
#
#
# diffusion_pytorch_model.bin:  92% 3.16G/3.44G [11:59<00:52, 5.28MB/s]
#
#
# diffusion_pytorch_model.bin:  92% 3.16G/3.44G [11:59<00:37, 7.30MB/s]
#
#
# diffusion_pytorch_model.bin:  92% 3.17G/3.44G [11:59<00:29, 9.23MB/s]
#
#
# diffusion_pytorch_model.bin:  92% 3.17G/3.44G [12:00<00:54, 4.95MB/s]
#
#
# diffusion_pytorch_model.bin:  92% 3.17G/3.44G [12:01<01:24, 3.18MB/s]
#
#
# diffusion_pytorch_model.bin:  92% 3.17G/3.44G [12:01<01:26, 3.12MB/s]
#
#
# diffusion_pytorch_model.bin:  92% 3.17G/3.44G [12:01<01:29, 2.99MB/s]
#
#
# diffusion_pytorch_model.bin:  92% 3.17G/3.44G [12:02<01:05, 4.05MB/s]
#
#
# diffusion_pytorch_model.bin:  92% 3.17G/3.44G [12:02<00:54, 4.85MB/s]
#
#
# diffusion_pytorch_model.bin:  92% 3.18G/3.44G [12:02<00:35, 7.30MB/s]
#
#
# diffusion_pytorch_model.bin:  93% 3.18G/3.44G [12:03<00:28, 9.08MB/s]
#
#
# diffusion_pytorch_model.bin:  93% 3.18G/3.44G [12:03<00:28, 8.88MB/s]
#
#
# diffusion_pytorch_model.bin:  93% 3.18G/3.44G [12:05<01:36, 2.64MB/s]
#
#
# diffusion_pytorch_model.bin:  93% 3.19G/3.44G [12:05<01:33, 2.71MB/s]
#
#
# diffusion_pytorch_model.bin:  93% 3.19G/3.44G [12:05<01:33, 2.71MB/s]
#
#
# diffusion_pytorch_model.bin:  93% 3.19G/3.44G [12:06<01:05, 3.82MB/s]
#
#
# diffusion_pytorch_model.bin:  93% 3.19G/3.44G [12:06<00:54, 4.52MB/s]
#
#
# diffusion_pytorch_model.bin:  93% 3.19G/3.44G [12:06<00:35, 6.84MB/s]
#
#
# diffusion_pytorch_model.bin:  93% 3.20G/3.44G [12:06<00:28, 8.56MB/s]
#
#
# diffusion_pytorch_model.bin:  93% 3.20G/3.44G [12:06<00:27, 8.58MB/s]
#
#
# diffusion_pytorch_model.bin:  93% 3.20G/3.44G [12:08<01:23, 2.86MB/s]
#
#
# diffusion_pytorch_model.bin:  93% 3.20G/3.44G [12:08<01:29, 2.65MB/s]
#
#
# diffusion_pytorch_model.bin:  93% 3.20G/3.44G [12:09<01:18, 3.00MB/s]
#
#
# diffusion_pytorch_model.bin:  93% 3.20G/3.44G [12:09<01:06, 3.53MB/s]
#
#
# diffusion_pytorch_model.bin:  93% 3.21G/3.44G [12:09<00:52, 4.40MB/s]
#
#
# diffusion_pytorch_model.bin:  93% 3.21G/3.44G [12:09<00:45, 5.05MB/s]
#
#
# diffusion_pytorch_model.bin:  93% 3.21G/3.44G [12:10<00:31, 7.24MB/s]
#
#
# diffusion_pytorch_model.bin:  93% 3.21G/3.44G [12:10<00:25, 8.95MB/s]
#
#
# diffusion_pytorch_model.bin:  94% 3.22G/3.44G [12:10<00:25, 8.80MB/s]
#
#
# diffusion_pytorch_model.bin:  94% 3.22G/3.44G [12:12<01:29, 2.48MB/s]
#
#
# diffusion_pytorch_model.bin:  94% 3.22G/3.44G [12:12<01:26, 2.56MB/s]
#
#
# diffusion_pytorch_model.bin:  94% 3.22G/3.44G [12:12<01:25, 2.58MB/s]
#
#
# diffusion_pytorch_model.bin:  94% 3.22G/3.44G [12:13<01:08, 3.21MB/s]
#
#
# diffusion_pytorch_model.bin:  94% 3.22G/3.44G [12:13<00:49, 4.36MB/s]
#
#
# diffusion_pytorch_model.bin:  94% 3.22G/3.44G [12:13<00:41, 5.20MB/s]
#
#
# diffusion_pytorch_model.bin:  94% 3.23G/3.44G [12:13<00:28, 7.34MB/s]
#
#
# diffusion_pytorch_model.bin:  94% 3.23G/3.44G [12:14<00:27, 7.71MB/s]
#
#
# diffusion_pytorch_model.bin:  94% 3.23G/3.44G [12:14<00:21, 9.44MB/s]
#
#
# diffusion_pytorch_model.bin:  94% 3.23G/3.44G [12:16<01:24, 2.45MB/s]
#
#
# diffusion_pytorch_model.bin:  94% 3.23G/3.44G [12:16<01:20, 2.55MB/s]
#
#
# diffusion_pytorch_model.bin:  94% 3.23G/3.44G [12:16<01:18, 2.59MB/s]
#
#
# diffusion_pytorch_model.bin:  94% 3.24G/3.44G [12:17<00:56, 3.58MB/s]
#
#
# diffusion_pytorch_model.bin:  94% 3.24G/3.44G [12:17<00:46, 4.30MB/s]
#
#
# diffusion_pytorch_model.bin:  94% 3.24G/3.44G [12:17<00:31, 6.26MB/s]
#
#
# diffusion_pytorch_model.bin:  94% 3.25G/3.44G [12:17<00:23, 8.31MB/s]
#
#
# diffusion_pytorch_model.bin:  94% 3.25G/3.44G [12:18<00:22, 8.50MB/s]
#
#
# diffusion_pytorch_model.bin:  94% 3.25G/3.44G [12:19<01:04, 2.92MB/s]
#
#
# diffusion_pytorch_model.bin:  94% 3.25G/3.44G [12:20<01:04, 2.91MB/s]
#
#
# diffusion_pytorch_model.bin:  95% 3.25G/3.44G [12:20<01:03, 2.97MB/s]
#
#
# diffusion_pytorch_model.bin:  95% 3.25G/3.44G [12:20<01:05, 2.87MB/s]
#
#
# diffusion_pytorch_model.bin:  95% 3.25G/3.44G [12:20<00:54, 3.40MB/s]
#
#
# diffusion_pytorch_model.bin:  95% 3.25G/3.44G [12:20<00:41, 4.47MB/s]
#
#
# diffusion_pytorch_model.bin:  95% 3.26G/3.44G [12:21<00:33, 5.40MB/s]
#
#
# diffusion_pytorch_model.bin:  95% 3.26G/3.44G [12:21<00:22, 7.88MB/s]
#
#
# diffusion_pytorch_model.bin:  95% 3.26G/3.44G [12:21<00:18, 9.64MB/s]
#
#
# diffusion_pytorch_model.bin:  95% 3.26G/3.44G [12:22<00:36, 4.76MB/s]
#
#
# diffusion_pytorch_model.bin:  95% 3.26G/3.44G [12:23<00:56, 3.09MB/s]
#
#
# diffusion_pytorch_model.bin:  95% 3.27G/3.44G [12:23<00:56, 3.04MB/s]
#
#
# diffusion_pytorch_model.bin:  95% 3.27G/3.44G [12:23<00:48, 3.53MB/s]
#
#
# diffusion_pytorch_model.bin:  95% 3.27G/3.44G [12:24<00:42, 4.04MB/s]
#
#
# diffusion_pytorch_model.bin:  95% 3.27G/3.44G [12:24<00:37, 4.51MB/s]
#
#
# diffusion_pytorch_model.bin:  95% 3.27G/3.44G [12:24<00:32, 5.13MB/s]
#
#
# diffusion_pytorch_model.bin:  95% 3.27G/3.44G [12:24<00:21, 7.66MB/s]
#
#
# diffusion_pytorch_model.bin:  95% 3.28G/3.44G [12:25<00:17, 9.29MB/s]
#
#
# diffusion_pytorch_model.bin:  95% 3.28G/3.44G [12:26<00:33, 4.76MB/s]
#
#
# diffusion_pytorch_model.bin:  95% 3.28G/3.44G [12:26<00:51, 3.08MB/s]
#
#
# diffusion_pytorch_model.bin:  95% 3.28G/3.44G [12:27<00:52, 3.01MB/s]
#
#
# diffusion_pytorch_model.bin:  95% 3.28G/3.44G [12:27<00:44, 3.53MB/s]
#
#
# diffusion_pytorch_model.bin:  96% 3.28G/3.44G [12:27<00:39, 3.91MB/s]
#
#
# diffusion_pytorch_model.bin:  96% 3.29G/3.44G [12:27<00:33, 4.59MB/s]
#
#
# diffusion_pytorch_model.bin:  96% 3.29G/3.44G [12:28<00:29, 5.06MB/s]
#
#
# diffusion_pytorch_model.bin:  96% 3.29G/3.44G [12:28<00:19, 7.48MB/s]
#
#
# diffusion_pytorch_model.bin:  96% 3.29G/3.44G [12:28<00:15, 9.16MB/s]
#
#
# diffusion_pytorch_model.bin:  96% 3.30G/3.44G [12:28<00:15, 9.19MB/s]
#
#
# diffusion_pytorch_model.bin:  96% 3.30G/3.44G [12:30<00:51, 2.78MB/s]
#
#
# diffusion_pytorch_model.bin:  96% 3.30G/3.44G [12:30<00:56, 2.52MB/s]
#
#
# diffusion_pytorch_model.bin:  96% 3.30G/3.44G [12:31<00:55, 2.52MB/s]
#
#
# diffusion_pytorch_model.bin:  96% 3.30G/3.44G [12:31<00:41, 3.38MB/s]
#
#
# diffusion_pytorch_model.bin:  96% 3.30G/3.44G [12:31<00:31, 4.34MB/s]
#
#
# diffusion_pytorch_model.bin:  96% 3.30G/3.44G [12:31<00:25, 5.28MB/s]
#
#
# diffusion_pytorch_model.bin:  96% 3.31G/3.44G [12:31<00:17, 7.45MB/s]
#
#
# diffusion_pytorch_model.bin:  96% 3.31G/3.44G [12:32<00:14, 9.17MB/s]
#
#
# diffusion_pytorch_model.bin:  96% 3.31G/3.44G [12:32<00:14, 8.94MB/s]
#
#
# diffusion_pytorch_model.bin:  96% 3.31G/3.44G [12:34<00:49, 2.55MB/s]
#
#
# diffusion_pytorch_model.bin:  96% 3.31G/3.44G [12:34<00:47, 2.63MB/s]
#
#
# diffusion_pytorch_model.bin:  96% 3.31G/3.44G [12:34<00:36, 3.36MB/s]
#
#
# diffusion_pytorch_model.bin:  96% 3.32G/3.44G [12:35<00:35, 3.43MB/s]
#
#
# diffusion_pytorch_model.bin:  97% 3.32G/3.44G [12:35<00:28, 4.26MB/s]
#
#
# diffusion_pytorch_model.bin:  97% 3.32G/3.44G [12:35<00:17, 6.75MB/s]
#
#
# diffusion_pytorch_model.bin:  97% 3.33G/3.44G [12:35<00:13, 8.46MB/s]
#
#
# diffusion_pytorch_model.bin:  97% 3.33G/3.44G [12:36<00:13, 8.52MB/s]
#
#
# diffusion_pytorch_model.bin:  97% 3.33G/3.44G [12:37<00:38, 2.86MB/s]
#
#
# diffusion_pytorch_model.bin:  97% 3.33G/3.44G [12:38<00:41, 2.61MB/s]
#
#
# diffusion_pytorch_model.bin:  97% 3.33G/3.44G [12:38<00:40, 2.69MB/s]
#
#
# diffusion_pytorch_model.bin:  97% 3.33G/3.44G [12:38<00:31, 3.41MB/s]
#
#
# diffusion_pytorch_model.bin:  97% 3.33G/3.44G [12:38<00:23, 4.41MB/s]
#
#
# diffusion_pytorch_model.bin:  97% 3.34G/3.44G [12:39<00:19, 5.25MB/s]
#
#
# diffusion_pytorch_model.bin:  97% 3.34G/3.44G [12:39<00:13, 7.39MB/s]
#
#
# diffusion_pytorch_model.bin:  97% 3.34G/3.44G [12:39<00:10, 9.08MB/s]
#
#
# diffusion_pytorch_model.bin:  97% 3.34G/3.44G [12:40<00:19, 4.88MB/s]
#
#
# diffusion_pytorch_model.bin:  97% 3.34G/3.44G [12:41<00:29, 3.15MB/s]
#
#
# diffusion_pytorch_model.bin:  97% 3.35G/3.44G [12:41<00:30, 3.09MB/s]
#
#
# diffusion_pytorch_model.bin:  97% 3.35G/3.44G [12:41<00:31, 2.96MB/s]
#
#
# diffusion_pytorch_model.bin:  97% 3.35G/3.44G [12:42<00:25, 3.59MB/s]
#
#
# diffusion_pytorch_model.bin:  97% 3.35G/3.44G [12:42<00:18, 4.73MB/s]
#
#
# diffusion_pytorch_model.bin:  97% 3.35G/3.44G [12:42<00:15, 5.52MB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.35G/3.44G [12:42<00:10, 7.74MB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.36G/3.44G [12:42<00:08, 9.41MB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.36G/3.44G [12:44<00:17, 4.58MB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.36G/3.44G [12:45<00:25, 3.04MB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.36G/3.44G [12:45<00:25, 2.99MB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.36G/3.44G [12:45<00:26, 2.87MB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.36G/3.44G [12:45<00:20, 3.64MB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.37G/3.44G [12:45<00:14, 4.99MB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.37G/3.44G [12:46<00:12, 5.63MB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.37G/3.44G [12:46<00:09, 6.90MB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.37G/3.44G [12:46<00:06, 9.61MB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [12:46<00:07, 8.91MB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [12:48<00:20, 3.07MB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [12:49<00:30, 1.99MB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [12:50<00:46, 1.30MB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [12:51<00:53, 1.12MB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [12:51<00:58, 1.03MB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [12:52<01:08, 877kB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [12:52<01:22, 723kB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [12:53<01:31, 650kB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [12:53<01:43, 576kB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [12:54<01:42, 580kB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [12:55<01:48, 543kB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [12:55<01:41, 575kB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [12:55<01:38, 590kB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [12:56<01:38, 590kB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [12:56<01:32, 626kB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [12:57<01:22, 699kB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [12:57<01:16, 746kB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [12:58<01:12, 784kB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [12:58<01:06, 851kB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [12:58<00:56, 986kB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [12:59<00:50, 1.08MB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [12:59<00:43, 1.24MB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.38G/3.44G [13:00<00:38, 1.38MB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.39G/3.44G [13:00<00:33, 1.58MB/s]
#
#
# diffusion_pytorch_model.bin:  98% 3.39G/3.44G [13:01<00:28, 1.80MB/s]
#
#
# diffusion_pytorch_model.bin:  99% 3.39G/3.44G [13:01<00:25, 2.02MB/s]
#
#
# diffusion_pytorch_model.bin:  99% 3.39G/3.44G [13:01<00:22, 2.23MB/s]
#
#
# diffusion_pytorch_model.bin:  99% 3.39G/3.44G [13:02<00:20, 2.39MB/s]
#
#
# diffusion_pytorch_model.bin:  99% 3.39G/3.44G [13:02<00:17, 2.78MB/s]
#
#
# diffusion_pytorch_model.bin:  99% 3.39G/3.44G [13:04<00:36, 1.28MB/s]
#
#
# diffusion_pytorch_model.bin:  99% 3.39G/3.44G [13:04<00:40, 1.13MB/s]
#
#
# diffusion_pytorch_model.bin:  99% 3.39G/3.44G [13:05<00:42, 1.09MB/s]
#
#
# diffusion_pytorch_model.bin:  99% 3.39G/3.44G [13:05<00:44, 1.03MB/s]
#
#
# diffusion_pytorch_model.bin:  99% 3.39G/3.44G [13:05<00:41, 1.10MB/s]
#
#
# diffusion_pytorch_model.bin:  99% 3.39G/3.44G [13:05<00:28, 1.56MB/s]
#
#
# diffusion_pytorch_model.bin:  99% 3.40G/3.44G [13:05<00:14, 3.00MB/s]
#
#
# diffusion_pytorch_model.bin:  99% 3.40G/3.44G [13:06<00:09, 4.24MB/s]
#
#
# diffusion_pytorch_model.bin:  99% 3.40G/3.44G [13:06<00:07, 5.39MB/s]
#
#
# diffusion_pytorch_model.bin:  99% 3.40G/3.44G [13:06<00:04, 7.96MB/s]
#
#
# diffusion_pytorch_model.bin:  99% 3.41G/3.44G [13:06<00:03, 9.68MB/s]
#
#
# diffusion_pytorch_model.bin:  99% 3.41G/3.44G [13:07<00:06, 4.94MB/s]
#
#
# diffusion_pytorch_model.bin:  99% 3.41G/3.44G [13:08<00:10, 2.81MB/s]
#
#
# diffusion_pytorch_model.bin:  99% 3.41G/3.44G [13:09<00:09, 2.88MB/s]
#
#
# diffusion_pytorch_model.bin:  99% 3.41G/3.44G [13:09<00:07, 3.62MB/s]
#
#
# diffusion_pytorch_model.bin:  99% 3.41G/3.44G [13:09<00:05, 4.53MB/s]
#
#
# diffusion_pytorch_model.bin:  99% 3.42G/3.44G [13:09<00:04, 5.27MB/s]
#
#
# diffusion_pytorch_model.bin:  99% 3.42G/3.44G [13:10<00:02, 7.44MB/s]
#
#
# diffusion_pytorch_model.bin: 100% 3.42G/3.44G [13:10<00:01, 9.08MB/s]
#
#
# diffusion_pytorch_model.bin: 100% 3.42G/3.44G [13:10<00:01, 8.95MB/s]
#
#
# diffusion_pytorch_model.bin: 100% 3.42G/3.44G [13:12<00:05, 2.58MB/s]
#
#
# diffusion_pytorch_model.bin: 100% 3.43G/3.44G [13:12<00:04, 2.80MB/s]
#
#
# diffusion_pytorch_model.bin: 100% 3.43G/3.44G [13:12<00:04, 2.89MB/s]
#
#
# diffusion_pytorch_model.bin: 100% 3.43G/3.44G [13:13<00:03, 3.46MB/s]
#
#
# diffusion_pytorch_model.bin: 100% 3.43G/3.44G [13:13<00:02, 4.36MB/s]
#
#
# diffusion_pytorch_model.bin: 100% 3.43G/3.44G [13:13<00:01, 5.17MB/s]
#
#
# diffusion_pytorch_model.bin: 100% 3.43G/3.44G [13:13<00:00, 7.30MB/s]
#
#
# diffusion_pytorch_model.bin: 100% 3.44G/3.44G [13:13<00:00, 8.62MB/s]
#
#
# diffusion_pytorch_model.bin: 100% 3.44G/3.44G [13:15<00:00, 4.32MB/s]
#
#
#
#
# Upload 6 LFS files: 100% 6/6 [13:15<00:00, 132.52s/it]
# Steps: 100% 400/400 [21:40<00:00,  3.25s/it, lr=1e-5, step_loss=0.0304]

# %%
# Stable Diffusion V1
from diffusers import StableDiffusionPipeline
import torch
from PIL import Image

model_path = "./sd_martin_valen-model-v1-2_400_demo"
pipe = StableDiffusionPipeline.from_pretrained(model_path, torch_dtype=torch.float16)
pipe.to("cuda")

# Run inference using ChatGPT prompts to acquire 4 image panels
image1 = pipe(prompt="black hoodie with a front half zipper by martin valen").images[0]
image1.save("ProductSnapAI_panel_1.png")

image2 = pipe(prompt="white hoodie with a blue design by martin valen").images[0]
image2.save("ProductSnapAI_panel_2.png")

image3 = pipe(prompt="stripped hoodie by martin valen").images[0]
image3.save("ProductSnapAI_panel_3.png")

image4 = pipe(prompt="camouflage hoodie by martin valen").images[0]
image4.save("ProductSnapAI_panel_4.png")

# Image grid helper function from HuggingFace
def image_grid(imgs, rows, cols):
    assert len(imgs) == rows*cols

    w, h = imgs[0].size
    grid = Image.new('RGB', size=(cols*w, rows*h))
    grid_w, grid_h = grid.size

    for i, img in enumerate(imgs):
        grid.paste(img, box=(i%cols*w, i//cols*h))
    return grid

all_images = [image1, image2, image3, image4]
grid = image_grid(all_images, rows=1, cols=4)
grid
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=2048x512 at 0x7FA0786BCA00>
